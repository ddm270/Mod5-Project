# %% [markdown]
# ## Modeling

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, recall_score, precision_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
import string
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime

# %matplotlib inline

# %%
df = pd.read_csv('clean_critics.csv', engine='python')

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df = df[df['clean_review'].notna()]
df = df[df['sent_class'].notna()]

# %%
df.head()
# Out:
#   Unnamed: 0        title       artist          label release_date  metascore  \
# 0          0  The Wanting  Glenn Jones  Thrill Jockey   2011-09-13       77.0
# 1          1  The Wanting  Glenn Jones  Thrill Jockey   2011-09-13       77.0
# 2          2  The Wanting  Glenn Jones  Thrill Jockey   2011-09-13       77.0
# 3          3  The Wanting  Glenn Jones  Thrill Jockey   2011-09-13       77.0
# 4          4  The Wanting  Glenn Jones  Thrill Jockey   2011-09-13       77.0
#
#   user_score              genre  \
# 0        tbd  Adult Alternative
# 1        tbd  Adult Alternative
# 2        tbd  Adult Alternative
# 3        tbd  Adult Alternative
# 4        tbd  Adult Alternative
#
#                                              summary              name  ...  \
# 0  The fourth solo acoustic album for the guitari...              Mojo  ...
# 1  The fourth solo acoustic album for the guitari...      Boston Globe  ...
# 2  The fourth solo acoustic album for the guitari...          AllMusic  ...
# 3  The fourth solo acoustic album for the guitari...  Drowned In Sound  ...
# 4  The fourth solo acoustic album for the guitari...        PopMatters  ...
#
#                                         clean_review  length word_count  \
# 0                                  best dreams oct p   103.0        8.0
# 1  jones furthers exploratory path hes committed ...   351.0       43.0
# 2  jones performances compositions years touched ...   372.0       56.0
# 3  wanting boasts technical excellence cosy welco...   197.0       20.0
# 4              makes space creates landscape invites   151.0       17.0
#
#   sentiment  negative  neutral  positive  sent_class  rating_sent  \
# 0    0.7845     0.000    0.225     0.775         1.0          1.0
# 1    0.9274     0.078    0.493     0.428         1.0          1.0
# 2    0.4767     0.000    0.812     0.188         1.0          1.0
# 3    0.8932     0.000    0.457     0.543         1.0          1.0
# 4    0.2732     0.000    0.656     0.344         1.0          1.0
#
#                                                sp_lm
# 0                                   good dream oct p
# 1  jones further exploratory path   s commit tran...
# 2  jones performances composition year touch them...
# 3  want boast technical excellence cosy welcoming...
# 4                 make space create landscape invite
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110768 entries, 0 to 110896
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         110768 non-null  object
#  1   artist        110768 non-null  object
#  2   label         110355 non-null  object
#  3   release_date  110768 non-null  object
#  4   metascore     110768 non-null  float64
#  5   user_score    110768 non-null  object
#  6   genre         110768 non-null  object
#  7   summary       109085 non-null  object
#  8   name          110768 non-null  object
#  9   date          43840 non-null   object
#  10  rating        110768 non-null  float64
#  11  review        110768 non-null  object
#  12  clean_review  110768 non-null  object
#  13  length        110768 non-null  float64
#  14  word_count    110768 non-null  float64
#  15  sentiment     110768 non-null  float64
#  16  negative      110768 non-null  float64
#  17  neutral       110768 non-null  float64
#  18  positive      110768 non-null  float64
#  19  sent_class    110768 non-null  float64
#  20  rating_sent   110768 non-null  float64
#  21  sp_lm         110768 non-null  object
# dtypes: float64(10), object(12)
# memory usage: 19.4+ MB

# %%
stopwords_list=stopwords.words('english')+list(string.punctuation)+['album','albums', 'songs', 'song', 'music', 'like', 'one']

# %% [markdown]
# ### Tokenize

# %%
tokenizer = RegexpTokenizer(r'[a-zA-Z0-9]+')

# %%
#function to remove all stopwords, punctuations & unimportant words from the reviews and make a list
def reduce(text):
    tokens = tokenizer.tokenize(text) # tokenize every review
    removed = [token.lower() for token in tokens if token.lower() not in stopwords_list]
    return removed

# %%
df['clean_review']=df['clean_review'].apply(str)

# %%
clean_reviews = df['clean_review']
target = df['sent_class']

# %%
# remove all stopwords, punctuations & unimportant words from the reviews and make a list
processed_data = list(map(reduce, clean_reviews))

# %%
processed_data
# Out:
# [['best', 'dreams', 'oct', 'p'],
#  ['jones',
#   'furthers',
#   'exploratory',
#   'path',
#   'hes',
#   'committed',
#   'tranquil',
#   'yet',
#   'compelling',
#   'acoustic',
#   'steelstring',
#   'guitar',
#   'compositions',
#   'built',
#   'thoughtful',
#   'open',
#   'tunings',
#   'kind',
#   'expressive',
#   'bottleneck',
#   'guitar',
#   'even',
#   'win',
#   'fail',
#   'even',
#   'banjo',
#   'great',
#   'swamp',
#   'way',
#   'rout'],
#  ['jones',
#   'performances',
#   'compositions',
#   'years',
#   'touched',
#   'themes',
#   'yearning',
#   'past',
#   'soft',
#   'echo',
#   'present',
#   'day',
#   'stand',
#   'reason',
#   'title',
#   'cover',
#   'arta',
#   'guitarplaying',
#   'cat',
#   'looking',
#   'moonshould',
#   'sum',
#   'feeling',
#   'wanting',
#   'well'],
#  ['wanting',
#   'boasts',
#   'technical',
#   'excellence',
#   'cosy',
#   'welcoming',
#   'atmosphere',
#   'simple',
#   'combination',
#   'perhaps',
#   'hugely',
#   'rewarding'],
#  ['makes', 'space', 'creates', 'landscape', 'invites'],
#  ['perhaps',
#   'whatever',
#   'hes',
#   'wishing',
#   'doesnt',
#   'something',
#   'personal',
#   'boring',
#   'tell'],
#  ['never',
#   'gets',
#   'beyond',
#   'either',
#   'producing',
#   'meditative',
#   'joyful',
#   'difference',
#   'millions',
#   'acoustic',
#   'much'],
#  ['continuation',
#   'grand',
#   'tradition',
#   'rather',
#   'feeble',
#   'descendant',
#   'jones',
#   'custom',
#   'tunings',
#   'strike',
#   'sourly',
#   'sweet',
#   'notes',
#   'occasionallyas',
#   'title',
#   'tracktouching',
#   'raga',
#   'modes',
#   'oct',
#   'p'],
#  ['continuum',
#   'gorgeously',
#   'produced',
#   'brilliantly',
#   'strippedtobasics',
#   'incorporates',
#   'blues',
#   'softfunk',
#   'r',
#   'b',
#   'folk',
#   'pop',
#   'sound',
#   'totally',
#   'owned',
#   'mayer',
#   'stretch',
#   'trying',
#   'describe',
#   'sound',
#   'continuum',
#   'color',
#   'light',
#   'work',
#   'legends',
#   'sting',
#   'eric',
#   'clapton',
#   'sade',
#   'stevie',
#   'ray',
#   'vaughan',
#   'steve',
#   'winwood'],
#  ['likely',
#   'first',
#   'couple',
#   'times',
#   'hear',
#   'may',
#   'wash',
#   'completely',
#   'yet',
#   'give',
#   'plays',
#   'mayers',
#   'unique',
#   'ability',
#   'reflect',
#   'human',
#   'condition',
#   'cannot',
#   'fail',
#   'charm'],
#  ['great', 'blueeyed', 'soul', 'record', 'dec', 'p'],
#  ['smart',
#   'breezy',
#   'deftly',
#   'fuses',
#   'love',
#   'oldschool',
#   'blues',
#   'r',
#   'b',
#   'natural',
#   'gift',
#   'sharp',
#   'melodies',
#   'wellconstructed',
#   'sep',
#   'p'],
#  ['mr',
#   'mayer',
#   'writing',
#   'good',
#   'ones',
#   'leanness',
#   'directness',
#   'distinguish',
#   'strongest',
#   'work'],
#  ['many',
#   'continuums',
#   'softer',
#   'adult',
#   'alternative',
#   'side',
#   'melodic',
#   'voice',
#   'warm',
#   'production',
#   'complex',
#   'riffs',
#   'thoughtful',
#   'lyrics',
#   'cure',
#   'violent',
#   'reactions',
#   'mayers',
#   'name',
#   'used',
#   'evoke'],
#  ['earlier',
#   'parade',
#   'bright',
#   'primary',
#   'colors',
#   'plaintive',
#   'melodies',
#   'come',
#   'delicious',
#   'shades',
#   'gray',
#   'oct',
#   'p'],
#  ['continuum',
#   'necessarily',
#   'contain',
#   'surething',
#   'pop',
#   'hit',
#   'mainstream',
#   'pop',
#   'rock',
#   'satisfying',
#   'beginning',
#   'end'],
#  ['tunes',
#   'shapely',
#   'throughout',
#   'continuum',
#   'musicianship',
#   'elegant',
#   'virtuosic',
#   'musics',
#   'lowkey',
#   'loveliness',
#   'dissipates',
#   'sleepinducing',
#   'softrock',
#   'haze'],
#  ['waiting',
#   'world',
#   'change',
#   'mayer',
#   'breathily',
#   'imagines',
#   'world',
#   'frat',
#   'boys',
#   'get',
#   'couches',
#   'people',
#   'sign',
#   'petitions',
#   'sigh',
#   'little',
#   'less',
#   'noodley',
#   'vultures',
#   'gravity',
#   'would',
#   'good',
#   'step',
#   'toward',
#   'reminding',
#   'us',
#   'mayer',
#   'really'],
#  ['laidback',
#   'ballads',
#   'mayers',
#   'forte',
#   'gets',
#   'worked',
#   'politically',
#   'minded',
#   'first',
#   'single',
#   'waiting',
#   'world',
#   'change',
#   'overeager',
#   'version',
#   'hendrixs',
#   'axis',
#   'bold',
#   'love',
#   'mood',
#   'tightens',
#   'unpleasantly'],
#  ['edge',
#   'songwriting',
#   'spitpolished',
#   'tasteful',
#   'production',
#   'continuum',
#   'doesnt',
#   'convince',
#   'heady',
#   'soulful',
#   'rock',
#   'mayers',
#   'creative',
#   'quantum',
#   'leap',
#   'forward'],
#  ['calmly',
#   'circles',
#   'career',
#   'themes',
#   'warmedover',
#   'palatable',
#   'guitar',
#   'weavings',
#   'girls',
#   'scary',
#   'girls',
#   'sad',
#   'getting',
#   'older',
#   'weird',
#   'home',
#   'nice'],
#  ['end',
#   'continuum',
#   'feels',
#   'littlemore',
#   'selfindulgent',
#   'effort',
#   'possiblypeaked',
#   'pop',
#   'star'],
#  ['couple',
#   'continuum',
#   'hint',
#   'mayer',
#   'capable',
#   'shed',
#   'perfectionist',
#   'skin',
#   'get',
#   'quick',
#   'emotions',
#   'nov',
#   'p'],
#  ['still',
#   'hard',
#   'tell',
#   'hes',
#   'bluesman',
#   'softrockers',
#   'body',
#   'vice',
#   'versa',
#   'continuum',
#   'sound',
#   'trying',
#   'figure'],
#  ['superb', 'slowburning', 'gravity', 'really', 'sound', 'nov', 'p'],
#  ['ultimately', 'dour', 'stuff', 'reminiscent', 'yogic', 'sting', 'dec', 'p'],
#  ['every', 'track', 'stellar', 'aug', 'p'],
#  ['easily', 'best', 'extensive', 'catalogue', 'covers'],
#  ['every', 'becomes', 'right', 'amount', 'torch', 'twang'],
#  ['makes',
#   'work',
#   'beyond',
#   'langs',
#   'ability',
#   'control',
#   'prickly',
#   'inspiring',
#   'material',
#   'sensuality'],
#  ['seems', 'oddly', 'lacking', 'passion'],
#  ['langs',
#   'expansive',
#   'delivery',
#   'makes',
#   'sound',
#   'overblown',
#   'places',
#   'oct',
#   'p'],
#  ['whats',
#   'missing',
#   'distinctive',
#   'arrangements',
#   'emotional',
#   'interpretations',
#   'material',
#   'would',
#   'stake',
#   'langs',
#   'claim',
#   'jul',
#   'p'],
#  ['bereft', 'joy', 'pain', 'made', 'name', 'oct', 'p'],
#  ['proves', 'hold', 'best', 'distressed', 'songstresses', 'jun', 'p'],
#  ['ms',
#   'yamagata',
#   'moved',
#   'beyond',
#   'slightly',
#   'jazzy',
#   'overtones',
#   'debut',
#   'ep',
#   'grandiose',
#   'readyforradio',
#   'singer',
#   'songwriter',
#   'pop',
#   'ages'],
#  ['yamagatas',
#   'voice',
#   'rare',
#   'gifts',
#   'vocal',
#   'quality',
#   'instantly',
#   'recognizable',
#   'distinctive',
#   'yet',
#   'somehow',
#   'classic',
#   'incredible',
#   'range',
#   'covers',
#   'sensual',
#   'lows',
#   'tender',
#   'melancholy',
#   'highs'],
#  ['yamagata',
#   'creates',
#   'feeling',
#   'another',
#   'time',
#   'place',
#   'conjures',
#   'imagery',
#   'rachael',
#   'sitting',
#   'dank',
#   'smoky',
#   'yet',
#   'quaint',
#   'piano',
#   'bar',
#   'playing',
#   'beautiful',
#   'intimate',
#   'crowd',
#   'people'],
#  ['happenstance',
#   'lush',
#   'brooding',
#   'kind',
#   'record',
#   'makes',
#   'sense',
#   'coming',
#   'headphones',
#   'late',
#   'night'],
#  ['unabashedly',
#   'lush',
#   'deeply',
#   'textured',
#   'pop',
#   'record',
#   'makes',
#   'apologies',
#   'radiofriendliness',
#   'adornments'],
#  ['impressive', 'debut', 'may', 'p'],
#  ['lacks',
#   'fiona',
#   'apples',
#   'emotional',
#   'complexity',
#   'lovely',
#   'original',
#   'debut',
#   'finds',
#   'romance',
#   'despair',
#   'jun',
#   'jul',
#   'p'],
#  ['writing', 'exceptional'],
#  ['carried', 'impressive', 'theatricality', 'jul', 'p'],
#  ['evokes',
#   'singersongwriter',
#   'atmospherics',
#   'carole',
#   'king',
#   'elton',
#   'john',
#   'jun',
#   'p'],
#  ['would', 'work', 'better', 'layers', 'cleverness', 'removed'],
#  ['theres',
#   'nothing',
#   'sets',
#   'apart',
#   'bevy',
#   'female',
#   'artists',
#   'holds',
#   'influences'],
#  ['feeling', 'jason', 'mrazs', 'leftovers', 'jul', 'p'],
#  ['theres', 'nothing', 'wrong', 'performance', 'undistinguished'],
#  ['sondheim',
#   'reared',
#   'old',
#   'van',
#   'dyke',
#   'parks',
#   'records',
#   'might',
#   'sound',
#   'sep',
#   'p'],
#  ['musical', 'scope', 'breathtaking', 'dec', 'p'],
#  ['takes',
#   'lush',
#   'orchestrated',
#   'pop',
#   'staggering',
#   'new',
#   'heights',
#   'nov',
#   'p'],
#  ['record', 'breathtaking', 'eccentric', 'opulence'],
#  ['scattered',
#   'past',
#   'works',
#   'wainwrights',
#   'skills',
#   'bubble',
#   'surface',
#   'repeated',
#   'listens'],
#  ['want', 'blows', 'cinemascope', 'size'],
#  ['staggeringly',
#   'ambitious',
#   'emotional',
#   'complexity',
#   'rarely',
#   'seen',
#   'pop',
#   'era',
#   'never',
#   'mind'],
#  ['despite', 'flamboyant', 'touches', 'caustic', 'camp', 'oct', 'p'],
#  ['whether',
#   'listen',
#   'closely',
#   'sonic',
#   'textures',
#   'cursory',
#   'fashion',
#   'scouting',
#   'allusions',
#   'galore',
#   'listen',
#   'youll',
#   'likely',
#   'appreciate',
#   'something',
#   'different'],
#  ['painful', 'backstory', 'gets', 'work', 'remains', 'lovely', 'luxuriant'],
#  ['wainwright',
#   'powers',
#   'observation',
#   'recall',
#   'morrissey',
#   'cole',
#   'porter'],
#  ['rufus',
#   'selfeffacing',
#   'clever',
#   'enough',
#   'keep',
#   'becoming',
#   'totally',
#   'insipid'],
#  ['topheavy',
#   'best',
#   'material',
#   'operatic',
#   'unconstrained',
#   'works',
#   'unfolded',
#   'within',
#   'first',
#   'half',
#   'hour'],
#  ['want',
#   'matches',
#   'eclecticism',
#   'poses',
#   'eponymous',
#   'debut',
#   'suffers',
#   'lack',
#   'memorable'],
#  ['unlike',
#   'previous',
#   'two',
#   'releases',
#   'wainwrights',
#   'musings',
#   'seem',
#   'less',
#   'focused',
#   'little',
#   'meandering',
#   'handful'],
#  ['arrangements',
#   'ponderous',
#   'vowelmasticating',
#   'vocal',
#   'languor',
#   'excessive',
#   'almost',
#   'wish',
#   'hed',
#   'go',
#   'whole',
#   'hog',
#   'cover',
#   'ave',
#   'maria',
#   'nov',
#   'p'],
#  ['lays', 'thick', 'drowns', 'pretty', 'surfaces', 'oct', 'p'],
#  ['would',
#   'seem',
#   'wainwright',
#   'traded',
#   'operatic',
#   'sensibilities',
#   'broadway',
#   'flair',
#   'tired',
#   'swapping',
#   'stilettos',
#   'orthopedic',
#   'loafers'],
#  ['couple',
#   'tracks',
#   'dipped',
#   'melodramatically',
#   'thick',
#   'strings',
#   'opener',
#   'sum',
#   'result',
#   'almost',
#   'much',
#   'take',
#   'whole',
#   'lp',
#   'sitting'],
#  ['confidence',
#   'blossomed',
#   'time',
#   'around',
#   'vocally',
#   'shes',
#   'never',
#   'sounded',
#   'good'],
#  ['naess',
#   'abetted',
#   'prettily',
#   'winsome',
#   'voice',
#   'seems',
#   'ever',
#   'perched',
#   'razors',
#   'edge',
#   'heartbreak',
#   'hope',
#   'easy',
#   'trick',
#   'part',
#   'pulls'],
#  ['fans',
#   'jewel',
#   'turned',
#   'recent',
#   'pop',
#   'conversion',
#   'find',
#   'solace',
#   'even',
#   'better',
#   'tunes',
#   'leona',
#   'naess',
#   'p'],
#  ['less',
#   'immediately',
#   'eargrabbing',
#   'previous',
#   'disc',
#   'selftitled',
#   'record',
#   'nonetheless',
#   'sinks',
#   'deeply',
#   'mere',
#   'handful',
#   'plays'],
#  ['sure',
#   'takes',
#   'time',
#   'sink',
#   'gets',
#   'hold',
#   'heart',
#   'wont',
#   'let',
#   'go'],
#  ['naess', 'quite', 'comfortable', 'doling', 'melodic', 'ditty', 'another'],
#  ['pleasant', 'strippeddown', 'also', 'little', 'limp', 'oct', 'p'],
#  ['often',
#   'beautifully',
#   'sung',
#   'always',
#   'pretty',
#   'still',
#   'seems',
#   'troubled',
#   'beyond',
#   'heartbreak'],
#  ['unlike',
#   'leona',
#   'naess',
#   'musician',
#   'leona',
#   'naess',
#   'nearly',
#   'forgettable',
#   'perfection',
#   'production',
#   'cardboard',
#   'cutout',
#   'lyrical',
#   'musical',
#   'themes'],
#  ['stone',
#   'navigates',
#   'way',
#   'confidence',
#   'prowess',
#   'passion',
#   'experimentation'],
#  ['thing',
#   'joss',
#   'stone',
#   'extraordinary',
#   'voice',
#   'misguided',
#   'ploy',
#   'soul',
#   'sessions',
#   'rootsproduced',
#   'slomo',
#   'cover',
#   'white',
#   'stripes',
#   'tune'],
#  ['record',
#   'benefits',
#   'homogenous',
#   'warm',
#   'feeling',
#   'intimate',
#   'setup',
#   'make',
#   'tracks',
#   'setting',
#   'stones',
#   'remarkable',
#   'voice',
#   'rather',
#   'intentionally',
#   'distracting',
#   'singers',
#   'limitations'],
#  ['theres',
#   'denying',
#   'intuitive',
#   'understanding',
#   'stone',
#   'often',
#   'daunting',
#   'material',
#   'tackles',
#   'mar',
#   'p'],
#  ['unique',
#   'phrasing',
#   'huge',
#   'voice',
#   'accents',
#   'dips',
#   'slips',
#   'never',
#   'overworking',
#   'trying',
#   'bring',
#   'attention',
#   'via',
#   'hollow',
#   'acrobatics'],
#  ['dichotomy',
#   'power',
#   'sultriness',
#   'final',
#   'tracks',
#   'greatest',
#   'asset',
#   'duality',
#   'provide',
#   'joss',
#   'stone',
#   'career',
#   'knows',
#   'limits'],
#  ['stone', 'shines', 'impressive', 'covers', 'set'],
#  ['stone',
#   'voice',
#   'remarkably',
#   'authentic',
#   'atmosphere',
#   'conjures',
#   'smoky',
#   'sleazy',
#   'pure',
#   'mid',
#   'detroit'],
#  ['singing', 'rich', 'mature', 'agile', 'showy', 'least', 'final', 'number'],
#  ['fine', 'start', 'mar', 'p'],
#  ['sessions', 'establishes', 'stone', 'formidable', 'interpreter'],
#  ['worthy', 'novelty', 'status'],
#  ['good', 'voice', 'good'],
#  ['signifiers',
#   'deep',
#   'soul',
#   'experience',
#   'husky',
#   'rich',
#   'timbre',
#   'confident',
#   'testifying',
#   'honeyed',
#   'transitions',
#   'ruefulness',
#   'grime',
#   'pain',
#   'arent',
#   'feb',
#   'p'],
#  ['norah', 'jones', 'give', 'hate', 'think', 'phenom', 'go', 'get', 'far'],
#  ['body', 'work', 'wonderland', 'hits', 'time'],
#  ['enjoyed', 'sound', 'feel', 'room', 'squares', 'feel', 'right', 'home'],
#  ['equally', 'available', 'yet', 'sophisticated'],
#  ['mayaer',
#   'talks',
#   'circles',
#   'hear',
#   'artist',
#   'facing',
#   'massive',
#   'success',
#   'retreating',
#   'dec',
#   'p'],
#  ['norah',
#   'jones',
#   'mayer',
#   'never',
#   'lets',
#   'personality',
#   'talk',
#   'elegant',
#   'melodies',
#   'unlike',
#   'range',
#   'oct',
#   'p'],
#  ['kind', 'record', 'hate', 'liking', 'dec', 'p'],
#  ['sophomore', 'effort', 'doesnt', 'many', 'drawbacks', 'might', 'assume'],
#  ['overall',
#   'heavier',
#   'things',
#   'snappier',
#   'say',
#   'bruce',
#   'hornsby',
#   'cd',
#   'rockin',
#   'emotiondrenched',
#   'latest',
#   'dashboard',
#   'confessional'],
#  ['hes',
#   'technically',
#   'adept',
#   'playing',
#   'blues',
#   'perfectly',
#   'clear',
#   'heartache',
#   'mayer',
#   'knows',
#   'emote',
#   'comes',
#   'morning',
#   'night',
#   'hearty',
#   'partying'],
#  ['sadly',
#   'mayers',
#   'idea',
#   'good',
#   'time',
#   'involves',
#   'hiring',
#   'jazz',
#   'musicians',
#   'make',
#   'sound',
#   'james',
#   'taylor',
#   'dec',
#   'p'],
#  ['fine',
#   'art',
#   'self',
#   'destruction',
#   'amazing',
#   'records',
#   'appear',
#   'seemingly',
#   'nowhere',
#   'within',
#   'couple',
#   'plays',
#   'sound',
#   'already',
#   'something',
#   'youve',
#   'listening',
#   'years',
#   'month',
#   'dec',
#   'p'],
#  ['voice',
#   'asserts',
#   'record',
#   'sinks',
#   'however',
#   'stand',
#   'production',
#   'variegates',
#   'sonic',
#   'grandeur',
#   'grounded',
#   'rock',
#   'verities'],
#  ['rich',
#   'heartrending',
#   'beauty',
#   'toughbutlovable',
#   'gutter',
#   'poetry',
#   'plenty',
#   'genuine',
#   'emotion'],
#  ['thankfully',
#   'malin',
#   'heart',
#   'tunes',
#   'pull',
#   'tatteredtroubadour',
#   'trip'],
#  ['malin',
#   'adams',
#   'managed',
#   'create',
#   'record',
#   'whose',
#   'fearless',
#   'classicism',
#   'part',
#   'point',
#   'dec',
#   'p'],
#  ['folk', 'countrytinged', 'tunes', 'melodic', 'deft', 'emotive', 'dec', 'p'],
#  ['impressive', 'look', 'malins', 'musical', 'maturation'],
#  ['malin',
#   'convincingly',
#   'wraps',
#   'tortured',
#   'warble',
#   'around',
#   'dustcaked',
#   'tunes',
#   'p'],
#  ['malins',
#   'personal',
#   'reflections',
#   'growing',
#   'child',
#   'divorce',
#   'seventies',
#   'almost',
#   'grown',
#   'give',
#   'fine',
#   'art',
#   'soul'],
#  ['youre',
#   'listening',
#   'begin',
#   'sound',
#   'playacting',
#   'malins',
#   'trying',
#   'sound',
#   'heroes',
#   'hes',
#   'trying',
#   'create',
#   'anything',
#   'thats'],
#  ['sounds', 'good', 'wallflowers', 'record', 'mar', 'p'],
#  ['long',
#   'ryders',
#   'proudthey',
#   'made',
#   'fine',
#   'worthy',
#   'followup',
#   'oeuvre'],
#  ['arrives',
#   'accomplished',
#   'rootsmusic',
#   'serves',
#   'reminder',
#   'band',
#   'legacy'],
#  ['joyous',
#   'recreation',
#   'theyve',
#   'always',
#   'done',
#   'best',
#   'performances',
#   'crisp',
#   'energized',
#   'taut',
#   'passionate',
#   'ever',
#   'ed',
#   'stasiums',
#   'production',
#   'smooth',
#   'natural',
#   'flattering',
#   'musicians',
#   'without',
#   'intruding',
#   'natural',
#   'punch'],
#  ['impressive',
#   'followup',
#   'career',
#   'fans',
#   'thought',
#   'long',
#   'splendid',
#   'entry',
#   'contemporary',
#   'americana',
#   'field',
#   'long',
#   'ryders',
#   'underappreciated',
#   'hand',
#   'crafting'],
#  ['psychedelic',
#   'country',
#   'soul',
#   'puts',
#   'right',
#   'back',
#   'top',
#   'world',
#   'helped',
#   'create',
#   'mar',
#   'p'],
#  ['long',
#   'ryders',
#   'show',
#   'wellequipped',
#   'take',
#   'leading',
#   'role',
#   'modern',
#   'americana'],
#  ['flow',
#   'together',
#   'create',
#   'oldschool',
#   'full',
#   'experience',
#   'record',
#   'pop',
#   'car',
#   'cd',
#   'player',
#   'repeat',
#   'long',
#   'singalong',
#   'journey'],
#  ['producer',
#   'ed',
#   'stasium',
#   'keeps',
#   'production',
#   'crisp',
#   'melodic',
#   'controlled',
#   'mar',
#   'p'],
#  ['mellow',
#   'moments',
#   'may',
#   'turn',
#   'alt',
#   'fans',
#   'alt',
#   'country',
#   'longtime',
#   'fans',
#   'find',
#   'dandy',
#   'mar',
#   'p'],
#  ['dove',
#   'finds',
#   'band',
#   'reinvigorated',
#   'also',
#   'taking',
#   'enormous',
#   'pleasure',
#   'activities',
#   'jun',
#   'p'],
#  ['little',
#   'indie',
#   'olive',
#   'branch',
#   'dove',
#   'welcoming',
#   'welcome',
#   'jul',
#   'p'],
#  ['sounds',
#   'considerable',
#   'credit',
#   'much',
#   'record',
#   'might',
#   'followed',
#   'jun',
#   'p'],
#  ['dove',
#   'punchy',
#   'ruefulness',
#   'benefits',
#   'sparkling',
#   'production',
#   'tom',
#   'gorman',
#   'paul',
#   'q',
#   'kolderie',
#   'donelly',
#   'working',
#   'since',
#   'time',
#   'throwing',
#   'muses'],
#  ['might',
#   'reasonably',
#   'expect',
#   'mature',
#   'edition',
#   'belly',
#   'would',
#   'seem',
#   'less',
#   'fiery',
#   'delivered',
#   'back',
#   'day',
#   'craft',
#   'could',
#   'hope',
#   'theres',
#   'bit',
#   'much',
#   'drift',
#   'enough',
#   'clear',
#   'focus',
#   'dove',
#   'qualify',
#   'true',
#   'return',
#   'form'],
#  ['dove',
#   'texturethere',
#   'nothing',
#   'immediate',
#   'feed',
#   'tree',
#   'star',
#   'offkilter',
#   'headrush',
#   'singles',
#   'nothing',
#   'hooky',
#   'bright',
#   'king',
#   'superconnected',
#   'layers',
#   'copious',
#   'amounts',
#   'digging',
#   'involved'],
#  ['comfortable',
#   'return',
#   'band',
#   'didnt',
#   'worry',
#   'fitting',
#   'particular',
#   'pop',
#   'rock',
#   'moment',
#   'back',
#   'day',
#   'still',
#   'enough',
#   'common',
#   'make',
#   'meaningful',
#   'quality'],
#  ['belly',
#   'might',
#   'take',
#   'conventional',
#   'approach',
#   'dove',
#   'proves',
#   'still',
#   'take',
#   'flight'],
#  ['rule',
#   'dove',
#   'meshes',
#   'good',
#   'might',
#   'accounted',
#   'small',
#   'disappointment',
#   'pretty',
#   'spectacular',
#   'accomplishment',
#   'group',
#   'semiretired',
#   'musicians',
#   'fifties'],
#  ['upbeat', 'episodes', 'outweighed', 'melancholic', 'drama', 'jun', 'p'],
#  ['although',
#   'feed',
#   'tree',
#   'super',
#   'connected',
#   'found',
#   'time',
#   'round',
#   'dove',
#   'coherent',
#   'collection',
#   'retains',
#   'belly',
#   'essence',
#   'acknowledging',
#   'passing',
#   'nighon',
#   'quarter',
#   'century'],
#  ['shaving',
#   'middling',
#   'cuts',
#   'heartstrings',
#   'stars',
#   'align',
#   'would',
#   'helped',
#   'overall',
#   'belly',
#   'comeback',
#   'runs',
#   'together',
#   'cranky',
#   'sea',
#   'relationship',
#   'angst'],
#  ['millsap',
#   'may',
#   'swifts',
#   'reputation',
#   'break',
#   'country',
#   'past',
#   'much',
#   'repudiation',
#   'arrangements',
#   'reveals',
#   'depth',
#   'range',
#   'millsaps',
#   'singing',
#   'talents',
#   'search',
#   'bigger',
#   'audience'],
#  ['makes',
#   'record',
#   'satisfying',
#   'millsap',
#   'winds',
#   'fusing',
#   'thoroughly',
#   'southern',
#   'sound',
#   'literate',
#   'folky',
#   'storytelling',
#   'means',
#   'arrangements',
#   'vibrant',
#   'alive',
#   'even',
#   'hes',
#   'evoking',
#   'styles',
#   'around',
#   'ages'],
#  ['latest',
#   'millsap',
#   'continuously',
#   'plays',
#   'tension',
#   'motion',
#   'stability',
#   'result',
#   'rewarding',
#   'weighty',
#   'lp',
#   'surely',
#   'serve',
#   'trusty',
#   'emotional',
#   'roadmap',
#   'years',
#   'come'],
#  ['slippery',
#   'perhaps',
#   'ways',
#   'interesting',
#   'enough',
#   'memorable',
#   'definitely',
#   'much',
#   'previous',
#   'work'],
#  ['adios',
#   'expands',
#   'nohit',
#   'wonder',
#   'incorporating',
#   'heaps',
#   'soul',
#   'pinch',
#   'sprightly',
#   'folk',
#   'swampy',
#   'blues',
#   'may',
#   'p'],
#  ['trio',
#   'creates',
#   'sound',
#   'cohesive',
#   'approach',
#   'unpredictable',
#   'expectation',
#   'heartland',
#   'rock',
#   'mingles',
#   'new',
#   'wave',
#   'agitations',
#   'swampy',
#   'blues',
#   'brushes',
#   'shoulders',
#   'swinging',
#   'waltzes'],
#  ['adios',
#   'sounds',
#   'hola',
#   'nearly',
#   'years',
#   'career',
#   'branan',
#   'sounds',
#   'finally',
#   'found',
#   'right',
#   'balance',
#   'audacity',
#   'subtlety',
#   'humor',
#   'heartbreak'],
#  ['representing',
#   'countrified',
#   'side',
#   'things',
#   'lead',
#   'single',
#   'imogene',
#   'warmly',
#   'sentimental',
#   'vow',
#   'show',
#   'branans',
#   'sides',
#   'diverse',
#   'wellcrafted',
#   'collection'],
#  ['branan',
#   'star',
#   'definitely',
#   'rise',
#   'played',
#   'rules',
#   'stuck',
#   'predictable',
#   'patterns',
#   'might',
#   'already',
#   'following',
#   'meandering',
#   'muse',
#   'making',
#   'journey',
#   'lot',
#   'interesting',
#   'fans',
#   'smart',
#   'country'],
#  ['branan',
#   'cant',
#   'quite',
#   'bring',
#   'full',
#   'circle',
#   'matching',
#   'emotions',
#   'results',
#   'leave',
#   'listener',
#   'craving',
#   'something',
#   'bit',
#   'substantial'],
#  ['adams',
#   'assembles',
#   'stunning',
#   'scrapbook',
#   'captures',
#   'heartbreak',
#   'intimate',
#   'array',
#   'snapshots',
#   'collection',
#   'marks',
#   'accomplished',
#   'record',
#   'since',
#   'heartbreaker'],
#  ['mostly',
#   'though',
#   'adams',
#   'seems',
#   'possessed',
#   'spirit',
#   'gets',
#   'pal',
#   'taylor',
#   'swift',
#   'hurt',
#   'sounds',
#   'savoring',
#   'full',
#   'life',
#   'matter',
#   'took',
#   'make',
#   'turned',
#   'misery',
#   'art',
#   'turned',
#   'joy'],
#  ['prisoner',
#   'differ',
#   'enough',
#   'recent',
#   'predecessors',
#   'stand',
#   'singular',
#   'midcareer',
#   'achievement',
#   'everprolific',
#   'songwriter',
#   'adams',
#   'fullyrealized',
#   'sturdy',
#   'collections',
#   'date',
#   'quite',
#   'possibly',
#   'finest',
#   'record',
#   'past',
#   'decade'],
#  ['prisoner',
#   'heartbreak',
#   'recordit',
#   'potentially',
#   'heartbreak',
#   'record',
#   'generation',
#   'least',
#   'turns',
#   'sadness',
#   'really',
#   'quite',
#   'currency'],
#  ['prisoner',
#   'filled',
#   'adams',
#   'reconciling',
#   'doubts',
#   'fears',
#   'life',
#   'love',
#   'faith',
#   'power',
#   'ultimatelythankfullymusic',
#   'wins',
#   'heartbreak',
#   'end'],
#  ['tails',
#   'strong',
#   'start',
#   'lyrically',
#   'though',
#   'view',
#   'adams',
#   'psychopathology',
#   'prisoner',
#   'nothing',
#   'short',
#   'fascinating'],
#  ['turns',
#   'set',
#   'fine',
#   'affecting',
#   'soft',
#   'rock',
#   'anything',
#   'say',
#   'still',
#   'love',
#   'introspective',
#   'disappear',
#   'recalls',
#   'paul',
#   'westerberg',
#   'intimate'],
#  ['adams',
#   'job',
#   'well',
#   'enough',
#   'willing',
#   'join',
#   'downward',
#   'spiral',
#   'maybe',
#   'listeners',
#   'locate',
#   'catharsis',
#   'eludes',
#   'lonely',
#   'living'],
#  ['record', 'wallows', 'hurt', 'functions', 'balm', 'bad', 'times'],
#  ['adams',
#   'breaking',
#   'new',
#   'ground',
#   'prisoner',
#   'seems',
#   'churlish',
#   'quibble',
#   'peak',
#   'powers'],
#  ['prisoner',
#   'must',
#   'tough',
#   'adams',
#   'write',
#   'record',
#   'ends',
#   'sounding',
#   'great',
#   'breakup',
#   'recent',
#   'times'],
#  ['prisoner',
#   'quite',
#   'careerbest',
#   'standards',
#   'predecessors',
#   'remarkably',
#   'focused',
#   'effective',
#   'successor',
#   'nonetheless'],
#  ['prisoner',
#   'works',
#   'well',
#   'deepwinter',
#   'heartbreak',
#   'acoustic',
#   'guitars',
#   'ruminations',
#   'loss',
#   'cutting',
#   'cold',
#   'air'],
#  ['prisoner', 'also', 'adamss', 'sonically', 'artful', 'date'],
#  ['theres', 'craft', 'galore', 'display', 'p'],
#  ['broken',
#   'heart',
#   'long',
#   'conductor',
#   'adamss',
#   'talentits',
#   'testament',
#   'quality',
#   'sounds',
#   'thoroughly',
#   'broken',
#   'time',
#   'mar',
#   'p'],
#  ['sombre', 'focused', 'affair', 'covers', 'taylor', 'swifts', 'mar', 'p'],
#  ['full',
#   'layers',
#   'little',
#   'emotions',
#   'rather',
#   'slave',
#   'bigger',
#   'issues',
#   'emotions',
#   'makes',
#   'authentic'],
#  ['beautiful',
#   'sounding',
#   'collection',
#   'question',
#   'sometimes',
#   'though',
#   'adams',
#   'exacting',
#   'justso',
#   'approach',
#   'sonics',
#   'undercuts',
#   'power',
#   'lyrics'],
#  ['contrast',
#   'interiority',
#   'sturdiness',
#   'compositions',
#   'striking',
#   'contrast',
#   'heartbreaker',
#   'lauded',
#   'solo',
#   'debut',
#   'ranking',
#   'breakup',
#   'records',
#   'ghoul',
#   'errand',
#   'suffice',
#   'say',
#   'loss',
#   'heartbreaker',
#   'fuel',
#   'turned',
#   'fumes'],
#  ['sometimes',
#   'almost',
#   'faithful',
#   'heroes',
#   'haunted',
#   'house',
#   'reconstructed',
#   'tunnel',
#   'love',
#   'right',
#   'titular',
#   'metaphor',
#   'songwriting',
#   'feels',
#   'personal',
#   'urgent',
#   'scholarship',
#   'see',
#   'rawbone',
#   'heartlandrocker',
#   'doomsday',
#   'gets',
#   'close',
#   'magnum',
#   'opus',
#   'dreams'],
#  ['spite',
#   'abundance',
#   'retro',
#   'rock',
#   'references',
#   'adams',
#   'gutspilling',
#   'lyricism',
#   'vulnerable',
#   'vocal',
#   'performances',
#   'waver',
#   'crack',
#   'tremble',
#   'still',
#   'give',
#   'prisoner',
#   'enough',
#   'heart',
#   'steer',
#   'clear',
#   'sounding',
#   'washedup',
#   'clich'],
#  ['ryan',
#   'adams',
#   'draws',
#   'well',
#   'sadness',
#   'confusion',
#   'seems',
#   'deepened',
#   'time',
#   'gets',
#   'closer'],
#  ['theyre',
#   'winners',
#   'tracks',
#   'lonesome',
#   'devastating',
#   'shiver',
#   'shake',
#   'prove',
#   'adams',
#   'remains',
#   'powerfully',
#   'evocative',
#   'songwriter',
#   'ever',
#   'mar',
#   'p'],
#  ['prisoner',
#   'th',
#   'release',
#   'obvious',
#   'homage',
#   'springsteens',
#   'earlyeighties',
#   'output',
#   'doesnt',
#   'stray',
#   'though',
#   'find',
#   'adams',
#   'heavyhanded',
#   'lyrically'],
#  ['another',
#   'downthemiddle',
#   'crowdpleasing',
#   'ryan',
#   'adams',
#   'record',
#   'time',
#   'crowd',
#   'expecting',
#   'bring',
#   'heat'],
#  ['prisoner',
#   'sticks',
#   'welltrodden',
#   'highways',
#   'whether',
#   'echoes',
#   'u',
#   'grand',
#   'guitar',
#   'stabs',
#   'earnest',
#   'vocal',
#   'tone',
#   'opener',
#   'still',
#   'love',
#   'spangly',
#   'flanged',
#   'guitars',
#   'relaxed',
#   'sense',
#   'space',
#   'lend',
#   'anything',
#   'say',
#   'laidback',
#   'stadium',
#   'sound',
#   'police'],
#  ['though',
#   'absolutely',
#   'gorgeous',
#   'production',
#   'recalls',
#   'lush',
#   'sound',
#   'synthscapes',
#   'rock',
#   'songwriting',
#   'weighed',
#   'clich'],
#  ['thing', 'adams', 'standards', 'many', 'sound', 'slightly', 'underwritten'],
#  ['ultimately',
#   'prisoner',
#   'tethered',
#   'sturdy',
#   'familiar',
#   'images',
#   'tightropes',
#   'trains',
#   'mar',
#   'p'],
#  ['fourth', 'satisfying', 'yet', 'feb', 'p'],
#  ['latest',
#   'jonny',
#   'fritz',
#   'cements',
#   'standing',
#   'firstrate',
#   'satirist',
#   'whose',
#   'offkilter',
#   'sensibility',
#   'expands',
#   'challenges',
#   'boundaries',
#   'constitutes',
#   'fair',
#   'game',
#   'pop',
#   'songwriting'],
#  ['astoundingly', 'distinctive'],
#  ['deliberately',
#   'murky',
#   'tone',
#   'courtesy',
#   'taylor',
#   'goldsmith',
#   'jim',
#   'james',
#   'doesnt',
#   'always',
#   'help',
#   'spite',
#   'sometimes',
#   'gimmicky',
#   'tone',
#   'sweet',
#   'creep',
#   'evidence',
#   'jonny',
#   'fritz',
#   'genuine',
#   'talent',
#   'firstrate',
#   'songwriter',
#   'luck',
#   'hell',
#   'let',
#   'guard',
#   'time',
#   'let',
#   'us',
#   'hear',
#   'without',
#   'persona',
#   'getting',
#   'way'],
#  ['clearly',
#   'heartfelt',
#   'meticulously',
#   'crafted',
#   'package',
#   'cult',
#   'artist',
#   'deserves',
#   'far',
#   'acclaim',
#   'respect',
#   'wider',
#   'audience',
#   'single',
#   'disc',
#   'nonboxed',
#   'set',
#   'rerelease',
#   'everything',
#   'classic',
#   'deserves',
#   'beautifully',
#   'realized',
#   'example',
#   'reissues',
#   'done'],
#  ['allen',
#   'writes',
#   'painter',
#   'renewing',
#   'familiar',
#   'materialin',
#   'case',
#   'poorly',
#   'behaved',
#   'men',
#   'resourceful',
#   'hookers',
#   'spanish',
#   'namesvia',
#   'quirks',
#   'perspective',
#   'peculiar',
#   'taste',
#   'details'],
#  ['initial',
#   'spin',
#   'listener',
#   'likely',
#   'understand',
#   'juarez',
#   'cult',
#   'appeal',
#   'indeed',
#   'allen',
#   'obsession',
#   'however',
#   'superbly',
#   'documented',
#   'excellent',
#   'liner',
#   'notes',
#   'art',
#   'prints',
#   'reproducing',
#   'lithographs',
#   'accompanied',
#   'initial',
#   'run',
#   'release',
#   'repeated',
#   'listens',
#   'quickly',
#   'juarez',
#   'clawing',
#   'brain',
#   'heart'],
#  ['fascinating',
#   'oddity',
#   'streaked',
#   'sex',
#   'violence',
#   'sorrow',
#   'sort',
#   'seedcorn',
#   'robert',
#   'rodriguez',
#   'aesthetic',
#   'presented',
#   'complete',
#   'lithographs',
#   'accompanied',
#   'original',
#   'albeit',
#   'cramped',
#   'cd',
#   'size'],
#  ['sparse',
#   'yet',
#   'driving',
#   'trenchant',
#   'visual',
#   'work',
#   'accompanying',
#   'noteworthy',
#   'elements',
#   'allen',
#   'four',
#   'decades',
#   'artist',
#   'stands',
#   'revisiting',
#   'juarez',
#   'stunning',
#   'poetry',
#   'lines',
#   'allen',
#   'words',
#   'piquant',
#   'kick',
#   'throughout',
#   'raunchy',
#   'pithy',
#   'richly',
#   'redolent'],
#  ['juarez',
#   'experience',
#   'break',
#   'heart',
#   'sweetness',
#   'alicia',
#   'dogwood',
#   'put',
#   'sting',
#   'whiskey',
#   'back',
#   'throat',
#   'hard',
#   'crass',
#   'thumping',
#   'border',
#   'palace',
#   'outta',
#   'law',
#   'sunny',
#   'southern',
#   'california'],
#  ['incisive',
#   'crime',
#   'story',
#   'ever',
#   'committed',
#   'groove',
#   'juarez',
#   'striking',
#   'surreal',
#   'torrid',
#   'twisted',
#   'pastiche',
#   'stirred',
#   'decadence',
#   'desire'],
#  ['countrytarnished',
#   'garage',
#   'indie',
#   'glamrock',
#   'edge',
#   'collection',
#   'tracks',
#   'disappointment',
#   'p'],
#  ['sound',
#   'great',
#   'band',
#   'evolving',
#   'times',
#   'even',
#   'times',
#   'try',
#   'soul',
#   'conscience'],
#  ['hard',
#   'truths',
#   'faced',
#   'bad',
#   'voodoo',
#   'gets',
#   'annihilated',
#   'throughout',
#   'unflinching',
#   'lifeaffirming',
#   'hardrocking',
#   'glory'],
#  ['going',
#   'history',
#   'pretty',
#   'much',
#   'expect',
#   'genre',
#   'veterans',
#   'catchy',
#   'threechord',
#   'country',
#   'distorted',
#   'guitars',
#   'plenty',
#   'punk',
#   'rock',
#   'attitude',
#   'smart',
#   'ass',
#   'lyrics'],
#  ['going',
#   'history',
#   'visceral',
#   'gutthumping',
#   'prettyclosetolive',
#   'whose',
#   'main',
#   'themes',
#   'astonishment',
#   'alive',
#   'still',
#   'inexplicably'],
#  ['twentyone',
#   'years',
#   'later',
#   'band',
#   'released',
#   'going',
#   'history',
#   'shows',
#   'even',
#   'band',
#   'tongue',
#   'cheek',
#   'send',
#   'david',
#   'koesh',
#   'followers',
#   'culturally',
#   'relevant',
#   'band',
#   'certainly',
#   'still'],
#  ['sturdy',
#   'rousing',
#   'crankitup',
#   'rocknroll',
#   'thats',
#   'sometimes',
#   'punk',
#   'sometimes',
#   'country',
#   'feb',
#   'p'],
#  ['soaring',
#   'ian',
#   'mclagandedicated',
#   'small',
#   'faces',
#   'cover',
#   'nothing',
#   'spiritual',
#   'centrepiece',
#   'set',
#   'every',
#   'arrives',
#   'crisp',
#   'melodies',
#   'burning',
#   'guitars',
#   'impassioned',
#   'vocals',
#   'apr',
#   'p'],
#  ['longtime',
#   'fans',
#   'rewarded',
#   'spades',
#   'newcomers',
#   'wacos',
#   'could',
#   'lot',
#   'worse',
#   'starting',
#   'journey'],
#  ['record',
#   'perfect',
#   'neither',
#   'rock',
#   'n',
#   'roll',
#   'neither',
#   'musicians',
#   'birthed',
#   'collection',
#   'passion',
#   'amusement'],
#  ['going',
#   'history',
#   'may',
#   'mark',
#   'sea',
#   'change',
#   'langford',
#   'company',
#   'humor',
#   'honkytonk',
#   'affable',
#   'fullbodied',
#   'sound',
#   'awesome',
#   'chance',
#   'catch'],
#  ['tracks',
#   'capture',
#   'hellforleather',
#   'energy',
#   'countrified',
#   'cruises',
#   'waco',
#   'brothers',
#   'renowned',
#   'live',
#   'shows',
#   'also',
#   'enjoys',
#   'diversions',
#   'early',
#   'rod',
#   'stewartlike',
#   'ballad',
#   'orphan',
#   'unlikely',
#   'spirited',
#   'cover',
#   'small',
#   'faces',
#   'nothing'],
#  ['dreams',
#   'luxuriate',
#   'arrangements',
#   'swept',
#   'along',
#   'gossamer',
#   'strings',
#   'silky',
#   'backing',
#   'vocals',
#   'apr',
#   'p'],
#  ['dreams',
#   'much',
#   'combs',
#   'expressive',
#   'voice',
#   'feels',
#   'lived',
#   'authentic',
#   'may',
#   'lack',
#   'gravitas',
#   'heroes',
#   'certainly',
#   'never',
#   'disservice'],
#  ['nashville',
#   'way',
#   'texas',
#   'singersongwriter',
#   'ups',
#   'game',
#   'selfassured',
#   'sweetly',
#   'melodic',
#   'sophomore',
#   'release'],
#  ['flawlessly',
#   'rendered',
#   'unoffending',
#   'fault',
#   'perfection',
#   'dreams',
#   'greatest',
#   'shortcoming'],
#  ['combination',
#   'vibrant',
#   'lighthearted',
#   'instrumentation',
#   'intelligent',
#   'lyrics',
#   'make',
#   'chinese',
#   'fountain',
#   'best',
#   'guitar',
#   'year'],
#  ['ultimately',
#   'growlers',
#   'sunny',
#   'disposition',
#   'incredibly',
#   'natural',
#   'economical',
#   'style',
#   'songcraft',
#   'carries',
#   'chinese',
#   'fountain',
#   'manages',
#   'impressive',
#   'feat',
#   'leaving',
#   'listener',
#   'utterly',
#   'satisfied',
#   'hungry'],
#  ['chinese',
#   'fountain',
#   'really',
#   'everything',
#   'would',
#   'expect',
#   'beach',
#   'grungers',
#   'still',
#   'fantastically',
#   'unique',
#   'sparkles',
#   'delightfully',
#   'fun',
#   'sheer',
#   'honesty'],
#  ['barbed',
#   'musings',
#   'dead',
#   'scenes',
#   'dull',
#   'boy',
#   'vacuous',
#   'hipsters',
#   'aforementioned',
#   'big',
#   'toe',
#   'add',
#   'lyrical',
#   'bite',
#   'sonically',
#   'barely',
#   'strays',
#   'good',
#   'vibes',
#   'territory'],
#  ['ultimately',
#   'chinese',
#   'fountain',
#   'turning',
#   'point',
#   'way',
#   'divisive',
#   'record',
#   'first',
#   'time',
#   'fans',
#   'something',
#   'disagree'],
#  ['chinese',
#   'fountain',
#   'remaining',
#   'true',
#   'band',
#   'beach',
#   'goth',
#   'essence',
#   'blessedly',
#   'direct',
#   'sharper',
#   'songwriting',
#   'engaging',
#   'melodies',
#   'center',
#   'every'],
#  ['nostalgic',
#   'lofi',
#   'jangle',
#   'reverb',
#   'surf',
#   'guitars',
#   'sound',
#   'weirdly',
#   'socal',
#   'version',
#   'coral',
#   'synths',
#   'nov',
#   'p'],
#  ['delights',
#   'discovered',
#   'fans',
#   'mac',
#   'demarco',
#   'grinning',
#   'sleaze',
#   'reedy',
#   'pop',
#   'best',
#   'coast',
#   'straight',
#   'tunefulness',
#   'uk',
#   'largely',
#   'overlooked',
#   'weird',
#   'dreams',
#   'clear',
#   'growlers',
#   'obsessing',
#   'gimmicks',
#   'borrowed',
#   'tropes',
#   'perfectly',
#   'capable',
#   'graduating',
#   'become',
#   'great',
#   'insightful',
#   'pop',
#   'band'],
#  ['bands',
#   'laconic',
#   'devilmaycare',
#   'charm',
#   'evident',
#   'throughout',
#   'track',
#   'set',
#   'seemingly',
#   'lacked',
#   'followthrough',
#   'ensure',
#   'deal',
#   'clovenhoofed',
#   'bifurcatedtailed',
#   'swindler',
#   'included',
#   'ability',
#   'conjure',
#   'hooks'],
#  ['every',
#   'tune',
#   'serves',
#   'moment',
#   'series',
#   'selfcontained',
#   'filmic',
#   'miniatures',
#   'whose',
#   'character',
#   'sketches',
#   'though',
#   'brief',
#   'utterly',
#   'memorable',
#   'sketches',
#   'accompanying',
#   'sonics',
#   'resonant'],
#  ['adams',
#   'finds',
#   'moments',
#   'quiet',
#   'beauty',
#   'rabblerousing',
#   'rock',
#   'sep',
#   'p'],
#  ['ryan',
#   'adams',
#   'might',
#   'uplifting',
#   'sure',
#   'outstanding',
#   'reaffirming',
#   'singular',
#   'talent',
#   'namesake'],
#  ['ryan',
#   'adams',
#   'carries',
#   'classic',
#   'hallmarks',
#   'ryan',
#   'adams',
#   'musician',
#   'tightly',
#   'condensed',
#   'essential',
#   'collection',
#   'polished',
#   'americana',
#   'p'],
#  ['record',
#   'created',
#   'entirely',
#   'terms',
#   'also',
#   'produced',
#   'finest',
#   'records',
#   'remarkable',
#   'career'],
#  ['ryan',
#   'adams',
#   'take',
#   'many',
#   'chances',
#   'records',
#   'adams',
#   'made',
#   'past',
#   'decade',
#   'also',
#   'cohesive',
#   'consistent',
#   'ever',
#   'made'],
#  ['though',
#   'overall',
#   'sound',
#   'ryan',
#   'adams',
#   'may',
#   'mask',
#   'hiding',
#   'lyrics',
#   'every',
#   'bit',
#   'heartbroken',
#   'confused',
#   'lost',
#   'struggling',
#   'ever'],
#  ['built', 'savoured', 'rushed', 'sep', 'p'],
#  ['ryan',
#   'adams',
#   'best',
#   'work',
#   'lot',
#   'sweat',
#   'record',
#   'feels',
#   'clearly',
#   'considered',
#   'enough',
#   'carefully',
#   'produced',
#   'maximize',
#   'adams',
#   'strengths'],
#  ['repeated',
#   'listens',
#   'unmask',
#   'ryan',
#   'adams',
#   'great',
#   'record',
#   'sleek',
#   'departure',
#   'ashes',
#   'fire'],
#  ['theres',
#   'crystalline',
#   'gorgeousness',
#   'production',
#   'takes',
#   'homage',
#   'territory',
#   'rarefied',
#   'league',
#   'recently',
#   'recalls',
#   'war',
#   'drugs',
#   'oct',
#   'p'],
#  ['puncture',
#   'gloss',
#   'make',
#   'greatest',
#   'first',
#   'impression',
#   'glimmer',
#   'remains',
#   'reason',
#   'get',
#   'lost',
#   'within',
#   'ryan',
#   'adams',
#   'blend',
#   'studio',
#   'craft',
#   'turns',
#   'eponymous',
#   'equivalent',
#   'substantive',
#   'new',
#   'millennial',
#   'version',
#   'eagles',
#   'long',
#   'run'],
#  ['much',
#   'best',
#   'work',
#   'slowburner',
#   'first',
#   'listen',
#   'sounds',
#   'pretty',
#   'decent',
#   'radiofriendly',
#   'record',
#   'repeated',
#   'plays',
#   'full',
#   'emotional',
#   'scale',
#   'adams',
#   'displaying',
#   'becomes',
#   'clear'],
#  ['haunt',
#   'hallowed',
#   'highs',
#   'love',
#   'hell',
#   'still',
#   'excellent',
#   'record',
#   'finds',
#   'adams',
#   'mojo',
#   'mercury',
#   'rise'],
#  ['records',
#   'better',
#   'view',
#   'ryan',
#   'adams',
#   'context',
#   'career',
#   'rather',
#   'makes',
#   'strong',
#   'contender',
#   'surprisingly',
#   'dense',
#   'field'],
#  ['far', 'losing', 'control', 'adams', 'sounds', 'total', 'command'],
#  ['selftitled',
#   'reflection',
#   'adams',
#   'continued',
#   'growth',
#   'songwriter',
#   'completely',
#   'relatable',
#   'anyone',
#   'managed',
#   'survive',
#   'marriagecreative',
#   'otherwiselong',
#   'past',
#   'honeymoon',
#   'phase'],
#  ['adams',
#   'contrary',
#   'character',
#   'darent',
#   'use',
#   'phrase',
#   'career',
#   'comeback',
#   'thats',
#   'oct',
#   'p'],
#  ['inevitable',
#   'heartbreakers',
#   'comparisons',
#   'new',
#   'offer',
#   'striking',
#   'contrast',
#   'petty',
#   'lyrical',
#   'point',
#   'view',
#   'petty',
#   'back',
#   'adams',
#   'theme',
#   'sounds',
#   'breakdown',
#   'seems',
#   'needy',
#   'depressing',
#   'tempered',
#   'adams',
#   'passion',
#   'rockhard',
#   'power',
#   'captures',
#   'kind',
#   'pain',
#   'excites'],
#  ['ryan',
#   'adams',
#   'strikes',
#   'best',
#   'balance',
#   'country',
#   'rock',
#   'found',
#   'yet'],
#  ['makes',
#   'ryan',
#   'adams',
#   'stunning',
#   'substance',
#   'restraint',
#   'sep',
#   'oct',
#   'p'],
#  ['dark',
#   'perilous',
#   'experience',
#   'hopes',
#   'light',
#   'end',
#   'adams',
#   'tunnel'],
#  ['best',
#   'record',
#   'sixth',
#   'seventh',
#   'still',
#   'triumph',
#   'sortsa',
#   'curious',
#   'meandering',
#   'journey',
#   'needs',
#   'made',
#   'good',
#   'times'],
#  ['adams',
#   'rewires',
#   'heartland',
#   'rock',
#   'majorchord',
#   'reaganera',
#   'guitars',
#   'muscleshirt',
#   'drums',
#   'thousandyard',
#   'stare'],
#  ['adams',
#   'occasionally',
#   'steps',
#   'puddle',
#   'shallow',
#   'adultcontemporary',
#   'tripe',
#   'even',
#   'incisive',
#   'personality',
#   'increasingly',
#   'tamed',
#   'voice',
#   'cannot',
#   'save',
#   'basic',
#   'imitations',
#   'past',
#   'great',
#   'adams',
#   'tunes',
#   'far',
#   'ryan',
#   'adams',
#   'particularly',
#   'weighed',
#   'recent'],
#  ['real',
#   'joy',
#   'adams',
#   'back',
#   'catalogue',
#   'vocal',
#   'mannerisms',
#   'skill',
#   'guitarist',
#   'allowed',
#   'take',
#   'versatile',
#   'approach',
#   'songwriting',
#   'evident',
#   'ryan',
#   'adams',
#   'aspect',
#   'suffer',
#   'lyricism'],
#  ['ryan', 'adams', 'much', 'ryan', 'adams', 'ryan', 'adams', 'oct', 'p'],
#  ['past',
#   'ventures',
#   'could',
#   'tend',
#   'exude',
#   'mannered',
#   'selfconsciousness',
#   'adams',
#   'acquits',
#   'easy',
#   'infectious',
#   'sincerity'],
#  ['handsome',
#   'melodic',
#   'hooks',
#   'sturdy',
#   'rootsmusic',
#   'grooves',
#   'downright',
#   'tom',
#   'pettyish',
#   'provide',
#   'hardwon',
#   'equilibrium',
#   'searching',
#   'relief',
#   'unspecified',
#   'ailments'],
#  ['ryan',
#   'adams',
#   'persuasively',
#   'dark',
#   'defined',
#   'themes',
#   'struggle',
#   'instability',
#   'isolation',
#   'regret'],
#  ['tthis',
#   'selftitled',
#   'monolithic',
#   'bombastic',
#   'urgent',
#   'doesnt',
#   'pay',
#   'listen',
#   'closely',
#   'lyrics',
#   'emerges',
#   'repetition'],
#  ['equally',
#   'whilst',
#   'real',
#   'lows',
#   'highs',
#   'equally',
#   'skyscraping',
#   'variety',
#   'let',
#   'go',
#   'ending',
#   'quiet',
#   'easily',
#   'forgettable',
#   'note'],
#  ['ryan',
#   'adams',
#   'better',
#   'worse',
#   'another',
#   'ryan',
#   'adams',
#   'recordbut',
#   'neither',
#   'adams',
#   'fans',
#   'seem',
#   'problem'],
#  ['much', 'refuses', 'stick', 'drifting', 'similarsounding', 'another'],
#  ['may',
#   'matured',
#   'last',
#   'years',
#   'theres',
#   'indication',
#   'thats',
#   'good',
#   'ryan',
#   'adams',
#   'feels',
#   'lazier',
#   'watered',
#   'ever'],
#  ['several',
#   'years',
#   'wandering',
#   'sonic',
#   'wilderness',
#   'parker',
#   'returned',
#   'roots',
#   'velvetfisted',
#   'vengeance',
#   'p'],
#  ['theres',
#   'blue',
#   'bird',
#   'heart',
#   'parker',
#   'circles',
#   'embrace',
#   'electric',
#   'guitar',
#   'crafty',
#   'songwriting',
#   'excellent',
#   'results'],
#  ['bluebird', 'heart', 'sound', 'great', 'artist', 'coming', 'back', 'home'],
#  ['filled',
#   'sound',
#   'fury',
#   'final',
#   'blow',
#   'ever',
#   'delivered',
#   'nonetheless',
#   'parker',
#   'created',
#   'knockout'],
#  ['superb', 'somewhat', 'restrained', 'blue', 'bird', 'heart'],
#  ['monsters',
#   'brit',
#   'expats',
#   'latest',
#   'recurring',
#   'skull',
#   'orchard',
#   'banner',
#   'embodies',
#   'qualities',
#   'langfords',
#   'best',
#   'work',
#   'emphasizing',
#   'bittersweet',
#   'introspective',
#   'edge',
#   'thats',
#   'become',
#   'increasingly',
#   'prominent',
#   'work',
#   'recent',
#   'years'],
#  ['little',
#   'doubt',
#   'monsters',
#   'day',
#   'considered',
#   'ensures',
#   'langford',
#   'legacy'],
#  ['langford',
#   'ever',
#   'masterfully',
#   'mixes',
#   'personal',
#   'political',
#   'poetic',
#   'apr',
#   'p'],
#  ['langford',
#   'may',
#   'lost',
#   'tiny',
#   'bit',
#   'ragged',
#   'glory',
#   'hes',
#   'gained',
#   'plenty',
#   'along',
#   'way',
#   'makes',
#   'must',
#   'whether',
#   'theyre',
#   'longtime',
#   'fans'],
#  ['langford', 'cynical', 'humor', 'fixture', 'monsters'],
#  ['monsters',
#   'sounds',
#   'fleshedout',
#   'band',
#   'graced',
#   'mekonsderived',
#   'musical',
#   'trademarks'],
#  ['dilution',
#   'purist',
#   'fidelity',
#   'makes',
#   'monsters',
#   'langford',
#   'least',
#   'focused',
#   'recent',
#   'memory',
#   'also',
#   'ends',
#   'richest'],
#  ['enjoy',
#   'skull',
#   'orchard',
#   'change',
#   'fact',
#   'naysayers',
#   'conspicuously',
#   'terrible',
#   'taste'],
#  ['ages',
#   'ages',
#   'undergone',
#   'lineup',
#   'changes',
#   'lots',
#   'peripheral',
#   'personal',
#   'battles',
#   'somehow',
#   'managed',
#   'internalize',
#   'later',
#   'deduce',
#   'navigate',
#   'avenues',
#   'lives',
#   'triumphantand',
#   'insanely',
#   'memorablesong',
#   'process',
#   'come',
#   'year',
#   'best',
#   'allaround'],
#  ['theres',
#   'deliciously',
#   'tangy',
#   'freshness',
#   'massed',
#   'voices',
#   'acoustic',
#   'thrum',
#   'apr',
#   'p'],
#  ['underlies',
#   'handclaps',
#   'radiant',
#   'melodies',
#   'sophomore',
#   'divisionary',
#   'noticeably',
#   'delve',
#   'deeper',
#   'philosophical',
#   'darker',
#   'themes',
#   'wideeyed',
#   'optimism',
#   'engulfed',
#   'debut',
#   'marks',
#   'evolution',
#   'band',
#   'undergone'],
#  ['occasionally',
#   'jaunty',
#   'positivity',
#   'treads',
#   'far',
#   'edward',
#   'sharpe',
#   'territory',
#   'left',
#   'craving',
#   'healthy',
#   'slice',
#   'cynicism'],
#  ['immediacy', 'impossible', 'escape'],
#  ['care',
#   'thing',
#   'rock',
#   'n',
#   'roll',
#   'country',
#   'american',
#   'general',
#   'depression',
#   'simply',
#   'essential'],
#  ['number',
#   'landmark',
#   'critics',
#   'quick',
#   'label',
#   'essential',
#   'given',
#   'fact',
#   'depression',
#   'jumpstarted',
#   'entire',
#   'genre',
#   'none',
#   'deserve',
#   'label',
#   'kudos',
#   'earned',
#   'good',
#   'uncle',
#   'clearly',
#   'well',
#   'earned'],
#  ['depression',
#   'legacy',
#   'edition',
#   'chronicles',
#   'collision',
#   'restlessness',
#   'ambition',
#   'portrays',
#   'band',
#   'successfully',
#   'wrangling'],
#  ['touchstones',
#   'depression',
#   'john',
#   'hardy',
#   'farrar',
#   'shows',
#   'flair',
#   'dynamic',
#   'skill',
#   'tweedy',
#   'works',
#   'bands',
#   'rocking',
#   'formula',
#   'train',
#   'guilelessly',
#   'narrates',
#   'small',
#   'town',
#   'life',
#   'screen',
#   'door',
#   'p'],
#  ['new',
#   'track',
#   'legacy',
#   'edition',
#   'ample',
#   'extrasrevvedup',
#   'outtakes',
#   'forlorn',
#   'covers',
#   'rare',
#   'live',
#   'cuts',
#   'best',
#   'strikingly',
#   'hungry',
#   'lofi',
#   'demosprovide',
#   'intriguing',
#   'peek',
#   'behind',
#   'curtain',
#   'young',
#   'band',
#   'flush',
#   'potential'],
#  ['challenging',
#   'appreciate',
#   'boldness',
#   'depression',
#   'extent',
#   'members',
#   'uncle',
#   'tupelo',
#   'insisted',
#   'interdependency',
#   'american',
#   'story',
#   'anymorefolks',
#   'selfidentify',
#   'way',
#   'hardly',
#   'anyone',
#   'loves',
#   'genre',
#   'monogamouslybut',
#   'still',
#   'something',
#   'furious',
#   'prideful',
#   'something',
#   'worth',
#   'hearing'],
#  ['expanded',
#   'reissue',
#   'adds',
#   'forever',
#   'demo',
#   'tape',
#   'got',
#   'signed',
#   'shows',
#   'vision',
#   'startlingly',
#   'complete',
#   'scrappiness',
#   'occasionally',
#   'serves',
#   'better'],
#  ['money',
#   'shot',
#   'still',
#   'original',
#   'track',
#   'stridently',
#   'argues',
#   'proves',
#   'thesis',
#   'uncle',
#   'tupelo',
#   'velvet',
#   'underground',
#   'altcountry'],
#  ['many',
#   'ways',
#   'demo',
#   'sounds',
#   'strong',
#   'rough',
#   'draft',
#   'followed',
#   'bit',
#   'less',
#   'electric',
#   'guitar',
#   'punch',
#   'shade',
#   'twang',
#   'documenting',
#   'performances',
#   'essentially',
#   'strong',
#   'terms',
#   'chops',
#   'commitment',
#   'spotting',
#   'subtle',
#   'differences',
#   'arrangements',
#   'fans',
#   'fun'],
#  ['odds',
#   'ends',
#   'packaged',
#   'end',
#   'disc',
#   'feel',
#   'jay',
#   'farrar',
#   'discarded',
#   'solo',
#   'offcuts',
#   'although',
#   'disc',
#   'two',
#   'collection',
#   'demos',
#   'intriguing',
#   'listen',
#   'ten',
#   'tracks',
#   'forever',
#   'tapes',
#   'persuaded',
#   'rockville',
#   'giant',
#   'sign',
#   'first',
#   'place'],
#  ['listening',
#   'uncle',
#   'tupelo',
#   'maiden',
#   'newly',
#   'expanded',
#   'form',
#   'underscores',
#   'essential',
#   'power',
#   'points',
#   'arbitrariness',
#   'watershed',
#   'reputation'],
#  ['amid',
#   'ballads',
#   'whiskey',
#   'bottle',
#   'graveyard',
#   'shift',
#   'shifts',
#   'pixiesesque',
#   'loud',
#   'quiet',
#   'parts',
#   'tweedy',
#   'illinois',
#   'twang',
#   'marks',
#   'grunge',
#   'peers',
#   'demos',
#   'might',
#   'expect',
#   'sketchy',
#   'stuff',
#   'therein',
#   'lies',
#   'appeal',
#   'digging',
#   'early',
#   'work',
#   'rock',
#   'pioneer'],
#  ['never',
#   'experienced',
#   'lucinda',
#   'williams',
#   'discovery',
#   'worth',
#   'making',
#   'live',
#   'heart',
#   'mind',
#   'long',
#   'disk',
#   'stops',
#   'spinning'],
#  ['williams',
#   'breakthrough',
#   'excellent',
#   'track',
#   'bonus',
#   'cd',
#   'offers',
#   'live',
#   'set',
#   'time',
#   'nice',
#   'radio',
#   'performances',
#   'mar',
#   'p'],
#  ['selftitled',
#   'released',
#   'uk',
#   'indie',
#   'rough',
#   'trade',
#   'began',
#   'journey',
#   'becoming',
#   'household',
#   'name',
#   'newly',
#   'remastered',
#   'disc',
#   'edition',
#   'lucinda',
#   'williams',
#   'blossoms'],
#  ['wellknown',
#   'perfectionist',
#   'took',
#   'eight',
#   'years',
#   'craft',
#   'release',
#   'tunes',
#   'fly',
#   'minutes',
#   'every',
#   'gem',
#   'first',
#   'title',
#   'williams',
#   'labela',
#   'new',
#   'due',
#   'mid',
#   'essential',
#   'listening',
#   'every',
#   'lucinda',
#   'fan',
#   'anyone',
#   'even',
#   'tangentially',
#   'touched',
#   'timeless'],
#  ['listening',
#   'proves',
#   'rarest',
#   'beasts',
#   'perfect',
#   'work',
#   'chord',
#   'lyric',
#   'beat',
#   'inflection',
#   'pull',
#   'heart',
#   'make',
#   'soar'],
#  ['trad',
#   'williams',
#   'tradrock',
#   'classics',
#   'instantly',
#   'recognizable',
#   'sgt',
#   'pepper',
#   'p'],
#  ['story', 'greatness', 'kind'],
#  ['hindsight',
#   'rough',
#   'trade',
#   'seamless',
#   'mix',
#   'folk',
#   'blues',
#   'country',
#   'cajun',
#   'rock',
#   'seen',
#   'launched',
#   'phenomenon',
#   'would',
#   'come',
#   'know',
#   'alt',
#   'country',
#   'feb',
#   'p'],
#  ['return',
#   'celebrated',
#   'bonus',
#   'disc',
#   'previously',
#   'unavailable',
#   'live',
#   'show',
#   'illustrates',
#   'formation',
#   'blueprint',
#   'tough',
#   'countryrock',
#   'literate',
#   'confessional',
#   'lyrics',
#   'would',
#   'serve',
#   'williams',
#   'well',
#   'next',
#   'quarter',
#   'century'],
#  ['americana', 'classic'],
#  ['finally', 'back', 'print', 'every', 'burns', 'hot', 'ever'],
#  ['defiant',
#   'confused',
#   'heartbreaking',
#   'hank',
#   'country',
#   'nutshell',
#   'jan',
#   'p'],
#  ['excellent',
#   'eighth',
#   'solo',
#   'finds',
#   'honouring',
#   'tradition',
#   'taking',
#   'pride',
#   'struggle',
#   'find',
#   'path'],
#  ['brothers',
#   'x',
#   'lively',
#   'flea',
#   'ants',
#   'pants',
#   'fizzing',
#   'tongueincheek',
#   'humour',
#   'lawless',
#   'punk',
#   'attitude',
#   'runs',
#   'poisoned',
#   'river',
#   'nov',
#   'p'],
#  ['fun', 'energetic', 'full', 'backcountry', 'outlaw', 'attitude'],
#  ['may',
#   'hard',
#   'country',
#   'fans',
#   'take',
#   'isnt',
#   'vital',
#   'artist',
#   'working',
#   'within',
#   'genre',
#   'right'],
#  ['mostly',
#   'wilting',
#   'pedal',
# ...
#   'reminds',
#   'us',
#   'good',
#   'soundtrack',
#   'bears',
#   'responsibility',
#   'good',
#   'cinema',
#   'show',
#   'us',
#   'possibilities',
#   'dreaming',
#   'minds',
#   'stitch',
#   'together'],
#  ['unmistakably', 'alluring', 'sep', 'p'],
#  ['anyone',
#   'expecting',
#   'something',
#   'akin',
#   'new',
#   'bj',
#   'rk',
#   'studio',
#   'recording',
#   'may',
#   'enjoy',
#   'drawing',
#   'restraint',
#   'taken',
#   'face',
#   'value',
#   'disc',
#   'rewarding',
#   'sidestep',
#   'aug'],
#  ['couple',
#   'really',
#   'cool',
#   'parts',
#   'rest',
#   'dont',
#   'feel',
#   'bad',
#   'forgetting'],
#  ['beauty', 'comes', 'forms', 'even', 'might', 'heads', 'oct', 'p'],
#  ['bj',
#   'rk',
#   'biggest',
#   'drawback',
#   'holographic',
#   'entrypoint',
#   'enlightening',
#   'rarity',
#   'bj',
#   'rk',
#   'fans',
#   'find',
#   'boring',
#   'boring'],
#  ['uneven', 'exceptionally', 'inventive', 'sep', 'p'],
#  ['haunting',
#   'results',
#   'may',
#   'distinctly',
#   'lacking',
#   'bjorks',
#   'musical',
#   'personality',
#   'greatest',
#   'asset',
#   'inimitable',
#   'voice',
#   'sep',
#   'p'],
#  ['crap', 'p'],
#  ['sad',
#   'thing',
#   'even',
#   'mainstream',
#   'bjorks',
#   'always',
#   'truly',
#   'artful',
#   'case',
#   'shes',
#   'merely',
#   'painted',
#   'vulgar',
#   'picture'],
#  ['children',
#   'moan',
#   'accordions',
#   'groan',
#   'bjorks',
#   'disembodied',
#   'voice',
#   'occasionally',
#   'growls',
#   'earshot',
#   'sep',
#   'p'],
#  ['else',
#   'madness',
#   'could',
#   'pull',
#   'covers',
#   'supremes',
#   'kinks',
#   'record',
#   'p'],
#  ['sessions',
#   'loose',
#   'fun',
#   'blazing',
#   'trails',
#   'doesnt',
#   'sound',
#   'bad',
#   'karaoke',
#   'night',
#   'either'],
#  ['dandy', 'little', 'party', 'record', 'aug', 'p'],
#  ['many', 'delight', 'listen', 'could', 'easily', 'single'],
#  ['even', 'covers', 'band', 'madness', 'remain', 'step', 'beyond', 'aug', 'p'],
#  ['shows', 'old', 'ska', 'formula', 'unimprovable', 'invention', 'sep', 'p'],
#  ['whilst',
#   'back',
#   'bounced',
#   'along',
#   'cheekiness',
#   'zeal',
#   'seem',
#   'trying',
#   'continue',
#   'reggaemeetsbritsuburbia',
#   'nutty',
#   'blueprint',
#   'end',
#   'falling',
#   'flat',
#   'many',
#   'places'],
#  ['dance', 'easily', 'weddings', 'good', 'news', 'aug', 'p'],
#  ['notable', 'exceptions', 'inspiration', 'lacks'],
#  ['done', 'trademark', 'chirpy', 'camden', 'ska', 'way', 'jul', 'p'],
#  ['bop',
#   'along',
#   'pace',
#   'interpreted',
#   'rocksteady',
#   'style',
#   'makes',
#   'proceedings',
#   'bit',
#   'wearisome',
#   'towards',
#   'end'],
#  ['nostalgic',
#   'trip',
#   'back',
#   'roots',
#   'makes',
#   'modestly',
#   'agreeable',
#   'listening',
#   'though',
#   'translation',
#   'raucous',
#   'pub',
#   'sober',
#   'recording',
#   'studio',
#   'squeezed',
#   'much',
#   'combos',
#   'spontaneous',
#   'lunacy'],
#  ['didnt', 'know', 'band', 'capable', 'would', 'good', 'enough', 'aug', 'p'],
#  ['scotts',
#   'aching',
#   'redemption',
#   'seething',
#   'revenge',
#   'tirades',
#   'give',
#   'sharp',
#   'contemporary',
#   'edge',
#   'sep',
#   'p'],
#  ['vitriol',
#   'however',
#   'tears',
#   'away',
#   'palatable',
#   'hooks',
#   'found',
#   'past',
#   'saliva',
#   'hits',
#   'isnt',
#   'necessarily',
#   'good',
#   'thing'],
#  ['memphis',
#   'fivepiece',
#   'sometimes',
#   'lacks',
#   'definitive',
#   'sound',
#   'yet',
#   'band',
#   'excels',
#   'straightforward',
#   'meatandpotatoes',
#   'sound'],
#  ['panders', 'unimaginative', 'industry', 'genre', 'posturing'],
#  ['would',
#   'better',
#   'without',
#   'scott',
#   'screaming',
#   'absolute',
#   'nonsense',
#   'sep',
#   'p'],
#  ['saliva',
#   'temper',
#   'midtempo',
#   'crunch',
#   'smetal',
#   'guitar',
#   'heroics',
#   'southernrock',
#   'fundamentalism',
#   'sep',
#   'p'],
#  ['boroughs',
#   'exciting',
#   'astonishing',
#   'balancing',
#   'act',
#   'fast',
#   'funny',
#   'sobering'],
#  ['picking',
#   'highlights',
#   'release',
#   'well',
#   'executed',
#   'downright',
#   'assshaking',
#   'difficult',
#   'boroughs',
#   'triumph'],
#  ['best', 'beasties', 'put', 'since', 'pauls', 'boutique'],
#  ['boroughs',
#   'greatest',
#   'strength',
#   'aural',
#   'cohesiveness',
#   'fueled',
#   'litany',
#   'golden',
#   'age',
#   'samples',
#   'heavy',
#   'often',
#   'dark',
#   'bassdriven',
#   'soundscapes',
#   'p'],
#  ['beats',
#   'simple',
#   'effective',
#   'welcome',
#   'lack',
#   'distracting',
#   'bells',
#   'whistles',
#   'made',
#   'hello',
#   'nasty',
#   'feel',
#   'overstuffed',
#   'jun',
#   'p'],
#  ['missy', 'elliott', 'beasties', 'reimagining', 'hiphopwhat', 'jun', 'p'],
#  ['signals',
#   'something',
#   'rebirth',
#   'signature',
#   'creativity',
#   'jul',
#   'aug',
#   'p'],
#  ['strikingly',
#   'minimal',
#   'throughout',
#   'emphasis',
#   'firmly',
#   'word',
#   'beastie',
#   'boys',
#   'plenty',
#   'left',
#   'say',
#   'jul',
#   'p'],
#  ['classics',
#   'theres',
#   'duds',
#   'either',
#   'given',
#   'beasties',
#   'pop',
#   'culture',
#   'aesthetic',
#   'seemed',
#   'territory',
#   'young',
#   'men',
#   'rather',
#   'impressive',
#   'theyre',
#   'maturing',
#   'gracefully',
#   'turning',
#   'expert',
#   'craftsmen',
#   'deliver',
#   'satisfying',
#   'listen'],
#  ['boroughs',
#   'unabashedly',
#   'travels',
#   'backward',
#   'missy',
#   'elliotts',
#   'similarly',
#   'retrominded',
#   'construction',
#   'joyful',
#   'makes',
#   'regression',
#   'feel',
#   'progressive',
#   'growth',
#   'overrated'],
#  ['unlike',
#   'previous',
#   'beastie',
#   'boys',
#   'possible',
#   'exception',
#   'licensed',
#   'ill',
#   'boroughs',
#   'sounds',
#   'homogenous',
#   'singular',
#   'purpose',
#   'dark',
#   'steel',
#   'dirty',
#   'incomplete',
#   'times',
#   'square',
#   'station'],
#  ['fun', 'hardly', 'fresh'],
#  ['honesty',
#   'sentiment',
#   'bothers',
#   'reviewer',
#   'rather',
#   'insertion',
#   'sentiment',
#   'ostensibly',
#   'lighthearted',
#   'romp',
#   'fun',
#   'return',
#   'days',
#   'old'],
#  ['formula', 'wears', 'thin', 'cuts', 'p'],
#  ['beastie',
#   'boys',
#   'always',
#   'best',
#   'gleefully',
#   'rhyming',
#   'stealing',
#   'variety',
#   'sourcesboth',
#   'musically',
#   'lyricallyand',
#   'selfimposed',
#   'adherence',
#   'hip',
#   'hop',
#   'traditionalism',
#   'indeed',
#   'musically',
#   'whole',
#   'rather',
#   'subdues',
#   'famously',
#   'freeform',
#   'sonic',
#   'palette',
#   'jul',
#   'p'],
#  ['boroughs', 'feels', 'theyre', 'sampling', 'aug', 'p'],
#  ['boroughs',
#   'continuously',
#   'distracted',
#   'titular',
#   'dedication',
#   'political',
#   'concerns',
#   'severely',
#   'dampening',
#   'replay',
#   'factor',
#   'also',
#   'proving',
#   'least',
#   'fun',
#   'normally',
#   'surefire',
#   'trio',
#   'made'],
#  ['imagine',
#   'hello',
#   'nasty',
#   'entirely',
#   'consisted',
#   'three',
#   'mcs',
#   'dj',
#   'youre',
#   'close',
#   'understanding',
#   'exactly',
#   'boroughs',
#   'sounds'],
#  ['tracks', 'crackle', 'swing', 'wit', 'lyrics', 'rarely', 'match'],
#  ['beats',
#   'bounce',
#   'along',
#   'happily',
#   'enough',
#   'strippeddown',
#   'sound',
#   'focuses',
#   'attention',
#   'antibush',
#   'lyrics',
#   'proves',
#   'undoing'],
#  ['lyrics', 'boroughs', 'exceptions', 'dismal', 'failure'],
#  ['sound',
#   'old',
#   'sound',
#   'past',
#   'sound',
#   'word',
#   'nobody',
#   'would',
#   'ever',
#   'thought',
#   'could',
#   'used',
#   'describe',
#   'beasties',
#   'irrelevant'],
#  ['mostly', 'sound', 'dated'],
#  ['part',
#   'fun',
#   'beastie',
#   'boys',
#   'knowing',
#   'theyre',
#   'fucking',
#   'rhymes',
#   'another',
#   'part',
#   'knowing',
#   'give',
#   'fuck',
#   'whats',
#   'happening',
#   'world',
#   'two',
#   'things',
#   'dont',
#   'always',
#   'work',
#   'well',
#   'together',
#   'though',
#   'especially',
#   'say',
#   'something',
#   'watered',
#   'deliver',
#   'though',
#   'dont',
#   'buy',
#   'either'],
#  ['beasties',
#   'boroughs',
#   'seem',
#   'scaredreluctant',
#   'innovate',
#   'serving',
#   'nonsense',
#   'lyrics',
#   'numbing',
#   'production',
#   'plain',
#   'lazy',
#   'sensing',
#   'theres',
#   'nowhere',
#   'go',
#   'better',
#   'establish',
#   'passable',
#   'holding',
#   'pattern',
#   'risk',
#   'inexcusable',
#   'backslide',
#   'toward',
#   'irrelevance'],
#  ['extreme', 'cd', 'date', 'june', 'p'],
#  ['released',
#   'best',
#   'best',
#   'pop',
#   'inflected',
#   'metal',
#   'since',
#   'system',
#   'downs',
#   'toxicity'],
#  ['least',
#   'two',
#   'thirds',
#   'still',
#   'comprised',
#   'headspinning',
#   'speed',
#   'metal',
#   'signs',
#   'genuine',
#   'progression',
#   'mention',
#   'progressive',
#   'rock'],
#  ['hardly',
#   'sellout',
#   'mellowing',
#   'shifting',
#   'direction',
#   'differing',
#   'textures',
#   'make',
#   'far',
#   'better',
#   'iowa'],
#  ['satisfying', 'carefully', 'crafted', 'representation', 'career', 'date'],
#  ['monsterchomp',
#   'guitars',
#   'semiauto',
#   'percussion',
#   'still',
#   'effect',
#   'somebody',
#   'spilled',
#   'little',
#   'pantene',
#   'pantera',
#   'jul',
#   'p'],
#  ['significant',
#   'broadening',
#   'tonal',
#   'spectrum',
#   'notwithstanding',
#   'outfit',
#   'manages',
#   'keep',
#   'ferocity',
#   'intact',
#   'although',
#   'malevolence',
#   'structured',
#   'shrewd',
#   'infusion',
#   'melodic',
#   'vocals',
#   'flourishing',
#   'experimental',
#   'dynamics',
#   'motherlode',
#   'striking',
#   'riffs'],
#  ['triumph', 'jul', 'p'],
#  ['basic', 'slipknot', 'sound', 'improved', 'p'],
#  ['slipknot',
#   'married',
#   'little',
#   'beauty',
#   'beast',
#   'schizophrenic',
#   'results',
#   'best',
#   'summed',
#   'line',
#   'thing',
#   'ever',
#   'really',
#   'loved',
#   'hate'],
#  ['ok',
#   'norah',
#   'jones',
#   'dinner',
#   'party',
#   'territory',
#   'enough',
#   'torturous',
#   'mayhem',
#   'gratify',
#   'faithful',
#   'maggots',
#   'equally',
#   'contrived',
#   'nature',
#   'underlying',
#   'habitual',
#   'havoc'],
#  ['plays',
#   'tepid',
#   'secondrate',
#   'version',
#   'iowa',
#   'pretty',
#   'much',
#   'makes',
#   'thirdrate',
#   'anything',
#   'else',
#   'jul',
#   'p'],
#  ['first',
#   'time',
#   'nearly',
#   'decade',
#   'cypress',
#   'hill',
#   'sound',
#   'really',
#   'enjoying',
#   'beginning'],
#  ['consistently', 'sold', 'apr', 'p'],
#  ['combination',
#   'mournful',
#   'maturity',
#   'clubready',
#   'fun',
#   'come',
#   'till',
#   'death',
#   'us',
#   'part',
#   'suits',
#   'fine'],
#  ['doesnt', 'break', 'formula', 'least', 'stretches'],
#  ['funkdriven',
#   'return',
#   'familiar',
#   'ground',
#   'laced',
#   'dark',
#   'imagery',
#   'beefy',
#   'hooks',
#   'sharp',
#   'vocal',
#   'trading',
#   'jun',
#   'p'],
#  ['long',
#   'time',
#   'part',
#   'till',
#   'death',
#   'sags',
#   'heavy',
#   'sense',
#   'j',
#   'vu',
#   'hinders',
#   'even',
#   'interesting',
#   'moments'],
#  ['attempts',
#   'genremashing',
#   'suffer',
#   'uncharacteristically',
#   'sluggish',
#   'muggs',
#   'production',
#   'may',
#   'p'],
#  ['production',
#   'good',
#   'divergent',
#   'styles',
#   'lack',
#   'cohesion',
#   'add',
#   'somewhat',
#   'schizophrenic',
#   'offering'],
#  ['cds', 'style', 'jumbling', 'never', 'coheres', 'mar', 'p'],
#  ['morbid', 'beats', 'never', 'heavy', 'subject', 'matter', 'may', 'p'],
#  ['third', 'enjoyable'],
#  ['strictly', 'devout', 'fan', 'base'],
#  ['franti',
#   'spearhead',
#   'almost',
#   'made',
#   'deliberate',
#   'attempt',
#   'stray',
#   'typical',
#   'hiphop',
#   'beats',
#   'go',
#   'something',
#   'bit',
#   'organic',
#   'acoustic',
#   'previous',
#   'efforts',
#   'experiments',
#   'pay'],
#  ['musically',
#   'vocally',
#   'frantis',
#   'confident',
#   'varied',
#   'work',
#   'date',
#   'jul',
#   'p'],
#  ['everyone',
#   'deserves',
#   'excels',
#   'beyond',
#   'simple',
#   'good',
#   'intentions',
#   'franti',
#   'spearhead',
#   'also',
#   'peace',
#   'musical',
#   'influences'],
#  ['always',
#   'undervalued',
#   'songwriter',
#   'franti',
#   'reassembles',
#   'familiar',
#   'building',
#   'blocks',
#   'rock',
#   'reggae',
#   'vintage',
#   'r',
#   'b',
#   'funkiest',
#   'inviting',
#   'neighborhoods',
#   'hes',
#   'yet',
#   'created'],
#  ['musical',
#   'stretches',
#   'spearhead',
#   'makes',
#   'go',
#   'long',
#   'way',
#   'toward',
#   'making',
#   'everyone',
#   'deserves',
#   'memorable',
#   'even',
#   'highly',
#   'recommended',
#   'affair',
#   'sanding',
#   'frantis',
#   'rougher',
#   'edges',
#   'prevents',
#   'essential',
#   'spearhead',
#   'fans',
#   'deserve',
#   'consistently',
#   'inspiring',
#   'fare',
#   'get'],
#  ['intelligent',
#   'wellcrafted',
#   'catchy',
#   'mix',
#   'funk',
#   'rap',
#   'soul',
#   'righton',
#   'sloganeering',
#   'jul',
#   'p'],
#  ['pieinthesky',
#   'ambitions',
#   'may',
#   'little',
#   'much',
#   'credit',
#   'franti',
#   'dreaming',
#   'kinder',
#   'gentler',
#   'new',
#   'world',
#   'order',
#   'sep',
#   'p'],
#  ['joyous',
#   'celebration',
#   'life',
#   'pulverizes',
#   'bullets',
#   'positive',
#   'vibes'],
#  ['musically',
#   'diverse',
#   'anything',
#   'band',
#   'ever',
#   'done',
#   'smoothly',
#   'vacillating',
#   'forceful',
#   'beats',
#   'heady',
#   'grooves'],
#  ['gets',
#   'right',
#   'rich',
#   'grooves',
#   'soulful',
#   'voices',
#   'sublime',
#   'early',
#   'curtis',
#   'mayfield',
#   'sly',
#   'family',
#   'stone'],
#  ['delivers',
#   'spiritual',
#   'political',
#   'message',
#   'thats',
#   'sensual',
#   'relevant',
#   'oct',
#   'p'],
#  ['seems',
#   'though',
#   'frantis',
#   'writing',
#   'morphed',
#   'messages',
#   'peace',
#   'love',
#   'personal',
#   'empowerment',
#   'without',
#   'context',
#   'doesnt',
#   'make',
#   'bad',
#   'per',
#   'se',
#   'closer',
#   'average'],
#  ['never',
#   'late',
#   'sounds',
#   'unhappy',
#   'mix',
#   'randy',
#   'newman',
#   'arrested',
#   'development',
#   'sometimes',
#   'franti',
#   'sounds',
#   'claphappy',
#   'seal',
#   'jul',
#   'p'],
#  ['taste',
#   'secret',
#   'skids',
#   'giddily',
#   'buoyant',
#   'beats',
#   'gently',
#   'satirical'],
#  ['total',
#   'effect',
#   'less',
#   'spin',
#   'feet',
#   'high',
#   'rising',
#   'hour',
#   'yogi',
#   'bear',
#   'cartoons',
#   'fine',
#   'hear',
#   'track',
#   'much',
#   'much',
#   'course',
#   'full'],
#  ['hilarious',
#   'critique',
#   'rightwing',
#   'reactionaries',
#   'hypocritical',
#   'lefties',
#   'hypercommercial',
#   'consumerism',
#   'slaveservice',
#   'industry',
#   'someone',
#   'smoked',
#   'lot',
#   'weed',
#   'turned',
#   'fast',
#   'food',
#   'nation',
#   'hit',
#   'broadway',
#   'musical'],
#  ['recommended', 'rap', 'fan', 'suffering', 'bling', 'fatigue', 'may', 'p'],
#  ['collage',
#   'pristine',
#   'partyhop',
#   'make',
#   'kids',
#   'bounce',
#   'purists',
#   'smile'],
#  ['jazzinfluenced', 'hiphop', 'sense', 'humor'],
#  ['goes',
#   'cold',
#   'fresh',
#   'glass',
#   'jazzy',
#   'jeff',
#   'fresh',
#   'prince',
#   'circa',
#   'sep',
#   'p'],
#  ['excavate', 'new', 'depths', 'frivolity', 'aug', 'p'],
#  ['quintets',
#   'molotov',
#   'mixture',
#   'suburb',
#   'surrealism',
#   'sonic',
#   'extremity',
#   'perfect',
#   'scrub',
#   'everything',
#   'youve',
#   'subjected',
#   'culture',
#   'daily',
#   'life',
#   'apr',
#   'p'],
#  ['prolific',
#   'beautiful',
#   'vital',
#   'statement',
#   'rock',
#   'since',
#   'stooges',
#   'raw',
#   'power'],
#  ['burn',
#   'piano',
#   'island',
#   'burn',
#   'must',
#   'first',
#   'listened',
#   'twice',
#   'wrap',
#   'head',
#   'around',
#   'peerless',
#   'vigor',
#   'skullrattling',
#   'force',
#   'revel',
#   'restless',
#   'creativity'],
#  ['sound',
#   'theyre',
#   'busy',
#   'tearing',
#   'limbs',
#   'hitting',
#   'another',
#   'head',
#   'think',
#   'actually',
#   'mean',
#   'apr',
#   'p'],
#  ['burn',
#   'piano',
#   'island',
#   'burn',
#   'balances',
#   'perfectly',
#   'commercial',
#   'appeal',
#   'untainted',
#   'creativity',
#   'band',
#   'digitally',
#   'inserted',
#   'atop',
#   'mountain',
#   'man',
#   'could',
#   'conceivably',
#   'climb'],
#  ['punklite', 'hits', 'cult', 'stardom', 'knocking', 'door', 'mar', 'p'],
#  ['admit',
#   'release',
#   'usually',
#   'manages',
#   'give',
#   'little',
#   'boost',
#   'listen',
#   'added',
#   'bonus',
#   'scaring',
#   'little',
#   'kids'],
#  ['whether',
#   'end',
#   'liking',
#   'going',
#   'intense',
#   'things',
#   'youve',
#   'ever',
#   'heard'],
#  ['bands',
#   'vital',
#   'disc',
#   'date',
#   'years',
#   'memorable',
#   'listening',
#   'experiences'],
#  ['blood',
#   'brothers',
#   'take',
#   'hardcore',
#   'incorporates',
#   'shouty',
#   'vocals',
#   'savage',
#   'guitar',
#   'riffing',
#   'hyperspeed',
#   'drumming',
#   'could',
#   'ask',
#   'throws',
#   'twosometimes',
#   'counterproductivevocalists',
#   'loopy',
#   'lyrics',
#   'aim',
#   'surrealist',
#   'poetry',
#   'usually',
#   'miss',
#   'badly',
#   'apr',
#   'p'],
#  ['clever',
#   'turns',
#   'dont',
#   'take',
#   'away',
#   'blood',
#   'brothers',
#   'ravaging',
#   'hardcore',
#   'band',
#   'instead',
#   'enlist',
#   'chops',
#   'service',
#   'manic',
#   'vision',
#   'insinuating',
#   'brutality'],
#  ['instant',
#   'lead',
#   'singer',
#   'jordan',
#   'blilie',
#   'whispering',
#   'passionately',
#   'ear',
#   'next',
#   'tears',
#   'insides',
#   'growls',
#   'piercing',
#   'youd',
#   'think',
#   'hed',
#   'transformed',
#   'savage',
#   'beast'],
#  ...]

# %% [markdown]
# ### Lemmatization

# %%
lemmatizer = WordNetLemmatizer()

# %%
lem_review = []
for j in processed_data:
    lem = ' '.join([lemmatizer.lemmatize(w) for w in j])
    lem_review.append(lem)

# %% [markdown]
# ### TF-IDF Vectorization

# %%
XL = lem_review
yL = target

# %%
XL_train, XL_test, yL_train, yL_test = train_test_split(XL, yL, test_size=0.2, random_state=1)
tfVectorizer = TfidfVectorizer()

XL_train_tf = tfVectorizer.fit_transform(XL_train)
XL_test_tf = tfVectorizer.transform(XL_test)

# %% [markdown]
# ### Baseline Model

# %%
#Fitting & predicting the Dummy Classifier (Baseline Model)
from sklearn.dummy import DummyClassifier
dclf = DummyClassifier()

# %%
dclf.fit(XL_train_tf, yL_train)
yL_preds = dclf.predict(XL_test_tf)
print('dummy accuracy:',accuracy_score(yL_test, yL_preds),
      'dummy forest f1:',f1_score(yL_test, yL_preds, average = 'weighted'))
# Out:
# dummy accuracy: 0.48132443161313604 dummy forest f1: 0.48142467455421245
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)

# %% [markdown]
# ### Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=250)

# %%
startTime = datetime.now()

rf_classifier.fit(XL_train_tf, yL_train)
yL_preds = rf_classifier.predict(XL_test_tf)
print('random forest accuracy:',accuracy_score(yL_test, yL_preds),
      'random forest f1:',f1_score(yL_test, yL_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# random forest accuracy: 0.8153644893540238 random forest f1: 0.7966156506921931
# 0:11:20.793319

# %% [markdown]
# ### Naive Bayes

# %%
nb_classifier = MultinomialNB()

# %%
startTime = datetime.now()

nb_classifier.fit(XL_train_tf, yL_train)
yL_preds = nb_classifier.predict(XL_test_tf)
print('naive bayes accuracy:',accuracy_score(yL_test, yL_preds),
      'naive bayes f1:',f1_score(yL_test, yL_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# naive bayes accuracy: 0.6492281303602059 naive bayes f1: 0.5132713495834365
# 0:00:00.190882

# %% [markdown]
# ### SVM - Final Model

# %%
svc_classifier = SVC(kernel='rbf', C= 1.0, class_weight = 'balanced')

# %%
startTime = datetime.now()

svc_classifier.fit(XL_train_tf, yL_train)
yL_preds = svc_classifier.predict(XL_test_tf)
print('support vector machine accuracy:',accuracy_score(yL_test, yL_preds),
      'support vector machine f1:',f1_score(yL_test, yL_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# support vector machine accuracy: 0.8425658607001083 support vector machine f1: 0.8437809748890294
# 0:58:18.315062

# %% [markdown]
# ### Grid SearchCV Naive Bayes Model

# %%
nb_params = {'alpha': [0.01,0.03,0.05,0.07,0.09,0.11,0.13,0.15,0.17,0.19],
              'fit_prior': [True, False],
              'class_prior': [[-1,0,1],[1,0,-1]]}

# %%
grid_nb = GridSearchCV(nb_classifier, param_grid=nb_params, cv=7, scoring='accuracy', verbose =1, n_jobs=-1)
grid_nb.fit(XL_train_tf, yL_train)
# Out:
# Fitting 7 folds for each of 40 candidates, totalling 280 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:    6.8s finished
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/sklearn/naive_bayes.py:488: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = np.log(class_prior)
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/sklearn/naive_bayes.py:488: RuntimeWarning: invalid value encountered in log
#   self.class_log_prior_ = np.log(class_prior)
# GridSearchCV(cv=7, estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13,
#                                    0.15, 0.17, 0.19],
#                          'class_prior': [[-1, 0, 1], [1, 0, -1]],
#                          'fit_prior': [True, False]},
#              scoring='accuracy', verbose=1)

# %%
# examine the best model
print(grid_nb.best_score_)
# Dictionary containing the parameters (min_samples_split) used to generate that score
print(grid_nb.best_params_)
# Shows default parameters that we did not specify
print(grid_nb.best_estimator_)
#Identify the best score during fitting with cross-validation
# Out:
# 0.641606893491904
# {'alpha': 0.01, 'class_prior': [1, 0, -1], 'fit_prior': True}
# MultinomialNB(alpha=0.01, class_prior=[1, 0, -1])

# %%
yL_preds = grid_nb.best_estimator_.predict(XL_test_tf)
print('naive bayes accuracy:',accuracy_score(yL_test, yL_preds),
      'naive bayes f1:',f1_score(yL_test, yL_preds, average = 'weighted'))
# Out:
# naive bayes accuracy: 0.6459761818837965 naive bayes f1: 0.5070367750809013

# %% [markdown]
# ### Modeling with spaCy
#
# Modeling review text spaCy was used to try to better process the large amount of text in the data and handle the context of the review and see if it resulted in better performing models.

# %%
XS = df['sp_lm']
yS = target

# %%
XS_train, XS_test, yS_train, yS_test = train_test_split(XS, yS, test_size=0.2, random_state=1)
tfVectorizer = TfidfVectorizer()

XS_train_tf = tfVectorizer.fit_transform(XS_train)
XS_test_tf = tfVectorizer.transform(XS_test)

# %% [markdown]
# #### Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=250)

# %%
startTime = datetime.now()

rf_classifier.fit(XS_train_tf, yS_train)
yS_preds = rf_classifier.predict(XS_test_tf)
print('random forest accuracy:',accuracy_score(yS_test, yS_preds),
      'random forest f1:',f1_score(yS_test, yS_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# random forest accuracy: 0.8061620353662937 random forest f1: 0.7853735547614679
# 0:10:40.732026

# %% [markdown]
# #### Naive Bayes

# %%
nb_classifier = MultinomialNB()

# %%
startTime = datetime.now()

nb_classifier.fit(XS_train_tf, yS_train)
yS_preds = nb_classifier.predict(XS_test_tf)
print('naive bayes accuracy:',accuracy_score(yS_test, yS_preds),
      'naive bayes f1:',f1_score(yS_test, yS_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# naive bayes accuracy: 0.6474197040779502 naive bayes f1: 0.510363029492351
# 0:00:00.078231

# %% [markdown]
# #### SVM

# %%
svc_classifier = SVC(kernel='linear', C = 1.0)

# %%
svc_classifier = SVC(kernel='rbf', C= 1.0, class_weight = 'balanced')

# %%
startTime = datetime.now()

svc_classifier.fit(XS_train_tf, yS_train)
yS_preds = svc_classifier.predict(XS_test_tf)
print('support vector machine accuracy:',accuracy_score(yS_test, yS_preds),
      'support vector machine f1:',f1_score(yS_test, yS_preds, average = 'weighted'))
print(datetime.now() - startTime)
# Out:
# support vector machine accuracy: 0.8360700108264164 support vector machine f1: 0.8380091409789721
# 0:57:06.546422
